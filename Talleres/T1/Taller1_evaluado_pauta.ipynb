# %% [markdown]
# <a href="https://colab.research.google.com/github/majorquev/Introduccion_a_ciencia_de_datos_R_v2/blob/main/Talleres/T1/Taller1_evaluado_pauta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción Ciencia de Datos con R: Taller 1
#
#
#
# Nombre 1: _Puede incluir su nombre acá haciendo doble click_                                                                                                                                      <br>
# Nombre 2: _Puede incluir su nombre acá haciendo doble click_
#
# # Instrucciones
#
# El siguiente test podrá desarrollarlo de manera individual o en pareja con otro(a) de sus compañeros(as).<br>
#
# Lea atentamente cada una de las preguntas propuestas y sea claro en los comentarios (si es que los incluye) de los desarrollos de sus respuestas. Para el desarrollo de las mismas, dispone de celdas de código después de cada pregunta. Sin embargo podrá agregar más celdas si así lo estima conveniente.<br>
# Las preguntas formuladas en este test pueden ser abordadas con las herramientas trabajadas en clases y ayudantía, sin embargo, usted podrá hacer uso de las funcionalidades y/o packages que estime convenientes, a menos que se indique explícitamente lo contrario.
#
# ## Tiempo y entrega
# Dispondrán hasta el día **domingo 26 de septiembre** hasta las 23:59 hrs para hacer envío de sus respuestas.
# Una vez finalizado el desarrollo del taller, deberá entregarlo teniendo en cuenta las siguientes consideraciones :
#
#  1. Descargue el notebook en **formato ipynb** (uno por pareja), e indique en el nombre del archivo los nombres de los integrantes, Taller1_nombres_integrantes.ipynb.
#     En caso de trabajar en Rstudio, deberá enviar el script de extensión *.R con el siguiente nombre: Taller1_nombres_integrantes.R , **procurando indicar con comentarios claros, qué pregunta está respondiendo en cada caso**.
#  * Envíe el archivo al correo rumorale1@gmail.com, con copia a majorquev@gmail.com con el **asunto** "ICD-SII-T1: 'nombre y apellido de los integrantes' "
#
# **NOTA**:
#    * Los correos cuyo asunto no comiencen con "ICD-SII-T1" no llegarán a destino y por ende no serán calificados.
#    * Los archivos que no contengan nombre serán calificados con la nota mínima 1.0.
#    * Los correos enviados posterior a la fecha y hora de entrega indicados tendrán una penalización de 1 punto por día (o fracción) de retraso en la entrega, por ejemplo, si usted envía sus respuestas a las 00:05 hrs del domingo 27 de septiembre, su nota máxima será un 6.0.

# %% [markdown]
# # Sección 1
#
# En la ruta `./datasets` se encuentran los siguientes arhivos, correspondiente a un sondeo de distintos restaurants del estado de California (CA) de EE.UU y sus valoraciones.
# El archivo `generalinfo.csv` contiene información propia del restaurant, como tipo de comida ofrecida y valoración de los clientes entre otros.
#
# * `id_restaurant`: Identificador del restaurant valorado.
# * `label`: Nombre del restaurant.
# * `food_type`: Tipo de comida ofrecida por el restaurant.
# * `review`: Calificación promedio del restaurant otorgada por los usuarios. (valor entre 0 y 1)
#
# Por otra parte, la información contenida en el archivo `location.csv` es la siguiente:
#
# * `id_rest`: Identificador del restaurant valorado.
# * `street_num`: Numeración de la ubicación del restaurant.
# * `street_name`: Nombre de la calle donde está ubicado el restaurant.
# * `city`: Ciudad donde se ubica el restaurant.
# * `county_name`: Condado.
# * `lat`: Latitud de la dirección.
# * `lng`: Longitud de la dirección.
# Note que ambas tablas están relacionadas a través de los campos `id_restaurant` y `id_rest`.
#
# ## Preliminar
# Cargue los archivos indicados previamente en dos variables, una llamada `general` y otra `location` para  `generalinfo.csv` y `location.csv` respectivamente.

# %%
#########
## Esto  no es necesaria en Rstudio, es sólo para modificar el tamaño de los gráficos desplegados en el notebook
library(repr)
options(repr.plot.width=12, repr.plot.height=12)
#########

## Carga de archivos
general <- read.csv("https://raw.githubusercontent.com/majorquev/Introduccion_a_ciencia_de_datos_R_v2/main/Talleres/T1/datasets/generalinfo.csv")
location <- read.csv("https://raw.githubusercontent.com/majorquev/Introduccion_a_ciencia_de_datos_R_v2/main/Talleres/T1/datasets/location.csv")


head(general,10);head(location,10)

#carga de lbrerías
library(dplyr)
library(ggplot2)
# Out:
#    id_restaurant label                    food_type     review
# 1   1            sparky's diner           24 hour diner 2.3
# 2   2            kabul afghan cuisine     afghani       3.8
# 3   3            helmand restaurant       afghani       4.0
# 4   4            afghani house            afghani       3.6
# 5   5            kabul afghan cusine      afghani       3.7
# 6   6            bamyan afghan restaurant afghani       2.8
# 7   7            kabul palace             afghani       2.8
# 8   8            kandahar                 afghani       3.5
# 9   9            kabobs house             afghani       2.7
# 10 10            massawa restaurant       african       3.4
#    id_rest street_num street_name                   city          county_name
# 1   1       242       church st                     san francisco San Francisco
# 2   2       135       el camino real                san carlos    San Mateo
# 3   3       430       broadway                      san francisco San Francisco
# 4   4      1103       e. el camino real             sunnyvale     Santa Clara
# 5   5       833       w. el camino real             sunnyvale     Santa Clara
# 6   6        NA                                     san rafael    Marin
# 7   7       155       san fernando                  san jose      Santa Clara
# 8   8      2118       mt diablo st                  concord       Contra Costa
# 9   9      3005       alamo drive (corner nut tree) vacaville     Solano
# 10 11       907       irving                        san francisco San Francisco
#    lat      lng
# 1  37.76665 -122.4291
# 2  37.51181 -122.2659
# 3  37.79845 -122.4044
# 4  37.35267 -122.0006
# 5  37.37100 -122.0416
# 6  37.97461 -122.5329
# 7  37.33332 -121.8919
# 8  37.97857 -122.0353
# 9  38.33546 -121.9547
# 10 37.76384 -122.4676
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ## Preguntas 1.1
#
# **P1a) (1pt)** Basándose en a tabla _general_, ¿cuántos restaurants (id's) distintos hay en total?<br>
# **P1b) (1pt)** ¿En cuántos tipos de comida diferentes se clasifican los restaurants?<br>
# **P1c) (2pt)** ¿Cuántas ciudades distintas considera el sondeo?<br>
# **P1d) (2pt)** ¿Indique el tipo de comida y las ciudades donde se encuentra el restaurant "great wall restaurant"?<br>
# **P1e) (2pt)** ¿Cuántos restaurantes de la ciudad de _san francisco_ tienen calificación mayor o igual a 3.8 y venden comida vegetariana (_vegetarian_) ?<br>

# %%
# P1.1
## Respusta 
#a) ---------------------------------------------------------------------
length(unique(general$id_restaurant))# 9590 restaurants
# También se considerarán los nombres distintos.
#b) ---------------------------------------------------------------------
length(unique(general$food_type)) # 145 tipos de comida distintos
#c) ---------------------------------------------------------------------
length(unique(location$city[!is.na(location$city)])) #167  ciudades distintas
#d) ---------------------------------------------------------------------
# Si no se explicita el uso de la funciónleft_join, igual se obtiene puntaje copleto. La utilización correcta de esta función se evalúa más adelante.
# se descuenta un punto si no indica correctamente las ciudades.
general %>% 
    filter(label == "great wall restaurant") %>%
    left_join(location,by = c("id_restaurant" = "id_rest")) 
# Tipo de comida: chinese, ciudades donde se ubica: San Francisco y San leandro.
#e) ---------------------------------------------------------------------
general %>%
    left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    filter(city == "san francisco" & review >= 3.8 & food_type == "vegetarian" ) %>% 
    nrow() # 3 restaurants
# Out:
# [1] 9590
# [1] 145
# [1] 167
#   id_restaurant label                 food_type review street_num street_name
# 1 3472          great wall restaurant chinese   2.0     4542      irving
# 2 3593          great wall restaurant chinese   2.5    15048      farnsworth st
#   city          county_name   lat      lng
# 1 san francisco San Francisco 37.76237 -122.5069
# 2 san leandro   Alameda       37.69065 -122.1514
# [1] 3

# %% [markdown]
# ## Preguntas 1.2
#
# **P2a) (2pt)** Sin considerar "san francisco", ¿cuál es la ciudad con mayor cantidad de restaurantes sondeados?<br>
# **P2b) (1pt)** ¿Cuáles son los 3 tipos de comida ofrecido más comunes ?<br>
# **P2c) (2pt)** Sin con siderar "san francisco", ¿Cuáles son las 3 ciudades con mayor cantidad de restaurants que ofrecen comido tipo _japanese_?<br>
# **P2d) (2pt)** Usted decide viajar a una de las ciudades en cuestión, para ello calcula el promedio de las valoraciones medias (promedio de _review_) por cada ciudad, y escoje aquella con mayor review promedio. ¿Qué ciudad escoge? <br>
# **P2e) (2pt)** Cuál es la ciudad con mejor valoración promedio de restaurantes tipo "barbeque"<br>

# %%
# P1.2
## Respusta 
#a) ---------------------------------------------------------------------
# general %>%
#     left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    location %>% 
    filter(city != "san francisco") %>% 
    count(city) %>% 
    arrange(-n) %>%
    head(1) # la ciudad con mayor número de restaurants es san jose, sin considerar san francisco.
#b) ---------------------------------------------------------------------
general %>% 
    count(food_type) %>%
    arrange(-n) %>%
    head(3) # café, comida china y pizza.
#c) ---------------------------------------------------------------------
general %>% 
    left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    filter(city != "san francisco" & food_type == "japanese") %>% 
    count(city) %>%
    arrange(-n) %>%
    head(3) # san jose, berkeley y oakland
#d) ---------------------------------------------------------------------
general %>% 
    left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    group_by(city) %>% 
    summarise(review_prom = mean(review)) %>%
    arrange(-review_prom) %>%
    head(1) # la ciudad de cerritos es la ciudad con mayor valoración promedio.
#e) ---------------------------------------------------------------------
#OPCION 1 (filtrar y luego agrupar)
general %>% 
    filter(food_type == "barbeque") %>%
    left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    group_by(city) %>% 
    summarise(review_prom = mean(review)) %>%
    arrange(-review_prom) %>%
    head(1) #pleasant hill con review_prom 3.7

#OPCION2 (agrupar y luego filtrar)
general %>% 
    left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    group_by(city,food_type) %>% 
    summarise(review_prom = mean(review)) %>%
    filter(food_type == "barbeque") %>%
    arrange(-review_prom) %>%
    head(1) #pleasant hill con review_prom 3.7
# Out:
#   city     n
# 1 san jose 933
#   food_type n
# 1 cafe      1098
# 2 chinese   1075
# 3 pizza      959
#   city     n
# 1 san jose 28
# 2 berkeley 14
# 3 oakland  14
#   city     review_prom
# 1 cerritos 3.8
#   city          review_prom
# 1 pleasant hill 3.7
# `summarise()` has grouped output by 'city'. You can override using the `.groups` argument.
#   city          food_type review_prom
# 1 pleasant hill barbeque  3.7

# %% [markdown]
# ## Preguntas 1.3
# **P3a) (4pt)** En la pregunta 1d), se pudo observar que un mismo restaurant puede estar presente en más de una ciudad. ¿Cuántos restaurants tienen esta característica, es decir están en más de una ciudad **distinta** ? De ser de utilidad puede investigar y utilizar la función `distinct()`.<br>
#
#
# **NOTA:** Si bien no es parte del objetivo de este taller, en ocasiones es necesario depurar la información obtenida a modo de trabajar con datos consistentes. En este análisis, en la tabla general, existen nombres de restaurantes que se peuden escribir de distinta manera (incluso con faltas de ortografía), por ejemplo:
#
#   * `"1/4 pound giant burger"` y  `"1/4 pound giant burgers"`
#   * `"3.6.9. shanghai restaurant"` y `"3 6 9 shanghai restaurant"`
#   * `"zorba's pizza"` y `"zorbas pizza"`
#
# Casos como estos existen muchos en nuestra tabla, pero para nuestros efectos **consideraremos como nombres distintos a aquellos casos como los mencionados anteriormente**.
#
# Una manera de abordar este tipo de inconsistencias es necesario en muchos casos la inclusión de diccionarios y de herramientas que nos permitan manipular texto, e incluso medir el nivel de similitud entre frases.
#
# A modo de ejemplo, se pueden eliminar los puntos, apóstrofes, guiones y otros caracteres de la siguiente manera:
#
# ````````
# general %>%
#     mutate(label = tolower(label)) %>% # se deja todo en minúsculas
#     mutate(label = gsub("'","", label)) %>% # se reemplaza "'" por ""
#     mutate(label = gsub(" ","_",label)) %>% # se reemplazan los espacios " " por "_"
#     mutate(label = chartr("áéíóú", "aeiou", label)) %>% head() # se eliminan las tildes
# ````````
#
# De ser de interés, pueden obtener más info sobre manipulación de textos y modelamiento en la siguiente referencia [https://www.tidytextmining.com/](https://www.tidytextmining.com/).<br>
# Package para medir similitud entre **palabras**: `stringdist`
#
# <br>
#
# **P3b) (2pt)** ¿Cuál es el restaurant que tiene presencia en la mayor cantidad de **ciudades distintas**?¿En cuántas ciudades está presente?<br>
# **P3c) (5pt)** Diremos que un restaurant posee _sucursales_ si en la tabla `general` existe más de un registro con el mismo `label`. Muestre, mediante un gráfico de barras, los 15 restaurants con  mayor cantidad de _sucursales_, donde la altura de la barra representa el total de sucursales de cada restaurant. Su gráfico debe contemplar al menos los siguientes aspectos:
#  * Debe contener un título.
#  * Debe incluir nombres sugerentes en los ejes.
#  * Los nombres de los restaurants deben ser legibles.
#  * Los restaurants deben ir ordenados según su cantidad de sucursales.
#  * Incluya tiquetas en la parte superior de cada barra, que muestre la cantidad de sucursales respectivas.
#  * Las leyendas de cada gráfico no deben visualizarse
#
# Como ayuda, puede ser de utilidad investigar la usabilidad de las siguientes funciones de ggplot2.
#   * `labs()`: Para la inclusión de nombres en los ejes, títulos, leyenda etc.
#   * `geom_label()`; `geom_text()`: para añadir etiquetas esobre las gráficas.
#   * `reorder()`: Para reordenar una variable en la función `aes()`.
#   * `coord_flip()`: Para invertir ejes.
#   * `theme()` en conjunto con `element_text()`: Permite modificar el tema de visualización. Por ejemplo, la siguiente instrucción muestra las etiquetas del eje x con una orientacíón en 45 grados respecto de la posición original:
#
#   ````````
# grafico_ggplot +
#     theme(axis.text.x=element_text(angle = 45, vjust = .5,hjust = 1))
#   ````````
#
#  A modo de ejemplo puede tener como referencia los siguientes gráficos.
#
#
#
# ![image.png](data:image/png;base64,...) !
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
# P3
## Respusta 
#a) ---------------------------------------------------------------------
#OPCION 1
general %>%
    left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    group_by(label) %>%
    distinct(city) %>% # dentro de cada "label", se retienen las ciudades distintas.
    summarise(n_city = n()) %>% # se cuenta el total de ciudades distintas 
    filter(n_city > 1) %>%
    nrow() #559 restaurants con presencia en más de una ciudad

#OPCION 2
general %>%
    left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    select(label,city) %>%
    distinct() %>% # también se puede utilizar unique()
    count(label) %>%
    filter(n > 1) %>%
    nrow()
#b) ---------------------------------------------------------------------
#mismo código de la parte anterior 
general %>%
    left_join(location,by = c("id_restaurant" = "id_rest")) %>%
    group_by(label) %>%
    distinct(city) %>% # dentro de cada "label", se retienen las ciudades distintas.
    summarise(n_city = n()) %>% # se cuenta el total de ciudades distintas 
    arrange(-n_city) %>%
    head(1) # baskin robbins con presencia en 49 ciudades
# Out:
# [1] 559
# [1] 559
#   label          n_city
# 1 baskin robbins 49

# %%
#c) ---------------------------------------------------------------------
general %>%
  count(label) %>%
  arrange(-n) %>%
  slice(1:15) %>% # o pueden usar head(), o bien generar una columna con el número de fila y luego filtrar
  ggplot() +
  aes(x = reorder(label,n), y = n , fill = n) + 
  geom_bar(stat = "identity", show.legend = FALSE) +
  coord_flip() +
  labs(x = "Restaurant",
       y = "Cantidad de sucursales",
       title = "Top 15 restaurants con mayor cantidad de sucursales",
       caption = "Ejemplo 1") +
  geom_label(aes(label = n),
            position = position_dodge(width = .9),
            vjust=-0.25,
            color = "#132B43",fill = "#FFC159")
# Out:
# plot without title

# %%
  general %>%
  count(label) %>%
  arrange(-n) %>%
  slice(1:15) %>% # o pueden usar head(), o bien generar una columna con el número de fila y luego filtrar
  ggplot() +
  aes(x = reorder(label,-n), y = n,fill = n) + 
  geom_bar(stat = "identity", show.legend = FALSE) +
  theme(axis.text.x=element_text(angle = 90, vjust = .5,hjust = 1)) +
  labs(x = "Restaurant",
         y = "Cantidad de sucursales",
         title = "Top 15 restaurants con mayor cantidad de sucursales",
         caption = "Ejemplo 2") +
    geom_text(aes(label = n),
               position = position_dodge(width = .9),
               vjust=-0.25) + 
    scale_fill_continuous(low = "#808080",
                          high = "#FFE600")
# Out:
# plot without title

# %% [markdown]
# ## Preguntas 1.4
#
# **P4a) (4pts)** Genere una tabla llamada `resumen`, que contenga la siguiente información:
#
#  * `city`: Ciudad
#  * `food_type`: Tipo de comida
#  * `n_rest`: Cantidad de restaurantes por cada ciudad y tipo de comida.
#  * `review_prom`: Valoración promedio por cada ciudad y tipo de comida.
#  * `total_rest`: Total de restaurantes por cada ciudad (se puede repetir el valor por cada tipo de comida).
#  * `review_prom_city`: Valoración promedio de los restaurantes por cada ciudad (se puede repetir el valor por cada tipo de comida).
#
# Su tabla deberá tener la siguiente estructura (la imgen sólo muestra los primeros registros):
#
# ![image.png](data:image/png;base64,...)
#
# **P4b) (2pts)** Basado en la tabla anterior, construya dos nuevas columnas llamadas `density_food_type` y `ratio_review` que contengan la siguiente información:
#
#  * `density_food_type`: Representa el cuociente entre le total de restaurants por tipo de comida y ciudad, respecto del total de restaurantes de la ciudad. (`n_rest/total_rest`)
#  * `ratio_review`: Representa el cociente entre a valoración del restaurant por tipo de comida y ciudad, respecto de la valoración promedio de los resturants de la misma ciudad. (`review_prom/review_prom_city`)
#
# **P4c) (3pts)** Mediante un gráfico de dispersión, muestre la relación entre `density_food_type` y `ratio_review`. Investigue sobre el parámetro `alpha` dentro de la capa geométrica para una mejor visualizaciónd de los puntos. Adicionalmente añada una curva de tendencia y, con base en él, indique si cabe la posibilidad de establecer algún tipo de dependencia entre `density_food_type` y `ratio_review`.

# %%
# P1.4
## Respusta 
#a) ---------------------------------------------------------------------
#OPCION 1
resumen_ciudad_tipo <- general %>% 
  left_join(location, by = c("id_restaurant" = "id_rest")) %>%
  group_by(city,food_type) %>%
  summarise(n_rest = n(),
            review_prom = mean(review)) 

resumen_ciudad <- general %>% 
  left_join(location, by = c("id_restaurant" = "id_rest")) %>%
  group_by(city) %>%
  summarise(total_rest = n(),
            review_prom_city = mean(review)) 

resumen <- resumen_ciudad_tipo %>%
    left_join(resumen_ciudad, by = "city") %>%
    arrange(-n_rest) 

head(resumen)
# Out:
# `summarise()` has grouped output by 'city'. You can override using the `.groups` argument.
#   city          food_type n_rest review_prom total_rest review_prom_city
# 1 san francisco chinese   172    2.345349    1241       2.490250
# 2 san francisco italian   142    2.641549    1241       2.490250
# 3 san jose      pizza     126    2.131746     933       2.193569
# 4 san jose      cafe      121    2.033884     933       2.193569
# 5 oakland       chinese   112    2.156250     666       2.194745
# 6 oakland       cafe       90    2.051111     666       2.194745

# %%
#OPCION 2
resumen <- general %>% 
  left_join(location, by = c("id_restaurant" = "id_rest")) %>%
  group_by(city,food_type) %>%
  summarise(n_rest = n(), 
           review_prom = mean(review)) %>%
  group_by(city) %>%
  mutate(total_rest = sum(n_rest),
        review_prom_city = sum(review_prom * n_rest)/total_rest) %>%
  arrange(-n_rest) 

head(resumen)
# Out:
# `summarise()` has grouped output by 'city'. You can override using the `.groups` argument.
#   city          food_type n_rest review_prom total_rest review_prom_city
# 1 san francisco chinese   172    2.345349    1241       2.490250
# 2 san francisco italian   142    2.641549    1241       2.490250
# 3 san jose      pizza     126    2.131746     933       2.193569
# 4 san jose      cafe      121    2.033884     933       2.193569
# 5 oakland       chinese   112    2.156250     666       2.194745
# 6 oakland       cafe       90    2.051111     666       2.194745

# %%
#b) ---------------------------------------------------------------------
resumen <- resumen %>% 
    mutate(
        density_food_type = n_rest/total_rest,
        ratio_review = review_prom/review_prom_city
    )

#c) ---------------------------------------------------------------------
resumen %>% 
    ggplot() +
    aes(x = density_food_type , y = ratio_review) + 
    geom_point(alpha = 0.3) + 
geom_smooth()
# según el gráfico, no se aprecia ningún tipo de dependencia entre ambas variables.
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# ## Preguntas 1.5
# **P5a) (3pts)** En la tabla `resumen` creada en **P4a)**, genere una nueva columna llamada `type_review`, que contenga "review alto", si `ratio_review >= 1` y "review bajo"  `ratio_review < 1`. ¿Qué indica esta variable? Comente.  <br>
# **P5b) (3pts)** Para cada `type_review`, muestre a través de un gráfico de cajas (boxplot), la distribución de la densidad del tipo de comida`density_food_type`. ¿Qué puede observar?<br>

# %%
#########
## Esto  no es necesaria en Rstudio, es sólo para modificar el tamaño de los gráficos desplegados en el notebook
library(repr)
options(repr.plot.width=9, repr.plot.height = 7)
#########

# P1.5
## Respusta 
#a) ---------------------------------------------------------------------
resumen <- resumen %>%
    mutate(type_review = ifelse(ratio_review >= 1, "review alto", "review bajo"))
    
# Reviw alto significa que la valoración promedio de este tipo de comida está por sobre la valoración promedio de los restaurants de la misma ciudad. 
# Reviw bajo significa que la valoración promedio de este tipo de comida está por debajo de la valoración promedio de los restaurants de la misma ciudad. 
#b) ---------------------------------------------------------------------
resumen %>%
    ggplot() +
    aes(x = type_review , y = density_food_type) + 
    geom_boxplot() 
# se puede observar que la mediana de density_food_type es levemente mayor para los casos con review alto (aunque quizá sea despreciable dicha diferencia). Además los casos con review bajo, aparentemente muestran una menor dispersión.
# Out:
# plot without title

# %% [markdown]
# # Sección 2
#
# En esta sección se busca explorar la relación entre la ubicación geográfica del restorant. Para ello, note que 504 de los 9590 registros de la tabla `location, no tienen las coordenadas geográficas del restorant en cuestión.
#
# Usted deberá encontrar dicha info, para lo cual deberá hacer uso de la api llamada _here_, disponible en el siguiente link  [https://developer.here.com/](https://developer.here.com/), con la que podrá consultar una dirección y obtener las coordenadas geográficas del texto buscado.
#
# Para poder utilizar esta API, usted deberá seguir los siguientes pasos

# %% [markdown]
# 1.   Crear una cuenta (recuerde escoger la opción _freemium_), y verificar su mail
#
# ![here_1.png](data:image/png;base64,...)
#
#
#
#
#
#
# ![here_2.png](data:image/png;base64,...)
# 2.   Cree una API key para poder utiliar la api. Para ello siga las instrucciones del iguiente link https://developer.here.com/documentation/authentication/dev_guide/topics/api-key-credentials.html

# %% [markdown]
# 3. Dentro de las distintas maneras de utilizar la API de HERE, usted puede buscar la geocodificación indicando el nombre de la calle, número, ciudad, estado, entre otros. Si desea obtener mayores detalles sobre las consultas y sus parámetros, puede consultar la documentación en el siguiente link, (https://developer.here.com/documentation/geocoding-search-api/api-reference-swagger.html). Aunque para efectos de esta evaluación basta poder realizar consultas como se muestra a continuación.
#
# Para verificar su conexión, pruebe generando la siguiente consulta

# %%
library(httr)
library(jsonlite)

# %%
url <-"https://geocoder.ls.hereapi.com/6.2/geocode.json?apiKey=1eC9b92fcoeD1sJMvfnZ48aHoMIFjBuPiiR9hF-9UKQ"

# %%
result <- GET(url,
                query = list(country   = "USA",
                             state ="CA",
                             city = "san francisco",
                             county = "San Francisco",
                             street = "church st",
                             housenumber = 242
                )
  )
  texto <- content(result, as = "text")
  contenido_lista <- fromJSON(texto)

result$status_code # Verifique que el status es 200
# Out:
# [1] 200

# %%
str(contenido_lista)
# Out:
# List of 1
#  $ Response:List of 2
#   ..$ MetaInfo:List of 1
#   .. ..$ Timestamp: chr "2021-09-24T02:38:23.702+0000"
#   ..$ View    :'data.frame':	1 obs. of  3 variables:
#   .. ..$ _type : chr "SearchResultsViewType"
#   .. ..$ ViewId: int 0
#   .. ..$ Result:List of 1
#   .. .. ..$ :'data.frame':	1 obs. of  5 variables:
#   .. .. .. ..$ Relevance   : num 1
#   .. .. .. ..$ MatchLevel  : chr "houseNumber"
#   .. .. .. ..$ MatchQuality:'data.frame':	1 obs. of  6 variables:
#   .. .. .. .. ..$ Country    : num 1
#   .. .. .. .. ..$ State      : num 1
#   .. .. .. .. ..$ County     : num 1
#   .. .. .. .. ..$ City       : num 1
#   .. .. .. .. ..$ Street     :List of 1
#   .. .. .. .. .. ..$ : num 1
#   .. .. .. .. ..$ HouseNumber: num 1
#   .. .. .. ..$ MatchType   : chr "pointAddress"
#   .. .. .. ..$ Location    :'data.frame':	1 obs. of  6 variables:
#   .. .. .. .. ..$ LocationId        : chr "NT_te3EecKD1Mgqf4-LPuP49A_yQjM"
#   .. .. .. .. ..$ LocationType      : chr "point"
#   .. .. .. .. ..$ DisplayPosition   :'data.frame':	1 obs. of  2 variables:
#   .. .. .. .. .. ..$ Latitude : num 37.8
#   .. .. .. .. .. ..$ Longitude: num -122
#   .. .. .. .. ..$ NavigationPosition:List of 1
#   .. .. .. .. .. ..$ :'data.frame':	1 obs. of  2 variables:
#   .. .. .. .. .. .. ..$ Latitude : num 37.8
#   .. .. .. .. .. .. ..$ Longitude: num -122
#   .. .. .. .. ..$ MapView           :'data.frame':	1 obs. of  2 variables:
#   .. .. .. .. .. ..$ TopLeft    :'data.frame':	1 obs. of  2 variables:
#   .. .. .. .. .. .. ..$ Latitude : num 37.8
#   .. .. .. .. .. .. ..$ Longitude: num -122
#   .. .. .. .. .. ..$ BottomRight:'data.frame':	1 obs. of  2 variables:
#   .. .. .. .. .. .. ..$ Latitude : num 37.8
#   .. .. .. .. .. .. ..$ Longitude: num -122
#   .. .. .. .. ..$ Address           :'data.frame':	1 obs. of  10 variables:
#   .. .. .. .. .. ..$ Label         : chr "242 Church St, San Francisco, CA 94114, United States"
#   .. .. .. .. .. ..$ Country       : chr "USA"
#   .. .. .. .. .. ..$ State         : chr "CA"
#   .. .. .. .. .. ..$ County        : chr "San Francisco"
#   .. .. .. .. .. ..$ City          : chr "San Francisco"
#   .. .. .. .. .. ..$ District      : chr "Castro"
#   .. .. .. .. .. ..$ Street        : chr "Church St"
#   .. .. .. .. .. ..$ HouseNumber   : chr "242"
#   .. .. .. .. .. ..$ PostalCode    : chr "94114"
#   .. .. .. .. .. ..$ AdditionalData:List of 1
#   .. .. .. .. .. .. ..$ :'data.frame':	4 obs. of  2 variables:
#   .. .. .. .. .. .. .. ..$ value: chr [1:4] "United States" "California" "San Francisco" "N"
#   .. .. .. .. .. .. .. ..$ key  : chr [1:4] "CountryName" "StateName" "CountyName" "PostalCodeType"

# %% [markdown]
# **P1) (2pts)** Observe los elementos de la lista anterior, y note que la latitud y longitud está guardadas en un data.frame llamado _DisplayPosition_. Para la consulta (lista) anterior, muestre cómo acceder a los valores de la latitud y longitud.
#
# **AYUDA:** ¿Qué clase de objeto es `contenido_lista$Response$View$Result`?
#
# ![image.png](data:image/png;base64,...)

# %%
class(contenido_lista$Response$View$Result)
str(contenido_lista$Response$View$Result)
# Out:
# [1] "list"
# List of 1
#  $ :'data.frame':	1 obs. of  5 variables:
#   ..$ Relevance   : num 1
#   ..$ MatchLevel  : chr "houseNumber"
#   ..$ MatchQuality:'data.frame':	1 obs. of  6 variables:
#   .. ..$ Country    : num 1
#   .. ..$ State      : num 1
#   .. ..$ County     : num 1
#   .. ..$ City       : num 1
#   .. ..$ Street     :List of 1
#   .. .. ..$ : num 1
#   .. ..$ HouseNumber: num 1
#   ..$ MatchType   : chr "pointAddress"
#   ..$ Location    :'data.frame':	1 obs. of  6 variables:
#   .. ..$ LocationId        : chr "NT_te3EecKD1Mgqf4-LPuP49A_yQjM"
#   .. ..$ LocationType      : chr "point"
#   .. ..$ DisplayPosition   :'data.frame':	1 obs. of  2 variables:
#   .. .. ..$ Latitude : num 37.8
#   .. .. ..$ Longitude: num -122
#   .. ..$ NavigationPosition:List of 1
#   .. .. ..$ :'data.frame':	1 obs. of  2 variables:
#   .. .. .. ..$ Latitude : num 37.8
#   .. .. .. ..$ Longitude: num -122
#   .. ..$ MapView           :'data.frame':	1 obs. of  2 variables:
#   .. .. ..$ TopLeft    :'data.frame':	1 obs. of  2 variables:
#   .. .. .. ..$ Latitude : num 37.8
#   .. .. .. ..$ Longitude: num -122
#   .. .. ..$ BottomRight:'data.frame':	1 obs. of  2 variables:
#   .. .. .. ..$ Latitude : num 37.8
#   .. .. .. ..$ Longitude: num -122
#   .. ..$ Address           :'data.frame':	1 obs. of  10 variables:
#   .. .. ..$ Label         : chr "242 Church St, San Francisco, CA 94114, United States"
#   .. .. ..$ Country       : chr "USA"
#   .. .. ..$ State         : chr "CA"
#   .. .. ..$ County        : chr "San Francisco"
#   .. .. ..$ City          : chr "San Francisco"
#   .. .. ..$ District      : chr "Castro"
#   .. .. ..$ Street        : chr "Church St"
#   .. .. ..$ HouseNumber   : chr "242"
#   .. .. ..$ PostalCode    : chr "94114"
#   .. .. ..$ AdditionalData:List of 1
#   .. .. .. ..$ :'data.frame':	4 obs. of  2 variables:
#   .. .. .. .. ..$ value: chr [1:4] "United States" "California" "San Francisco" "N"
#   .. .. .. .. ..$ key  : chr [1:4] "CountryName" "StateName" "CountyName" "PostalCodeType"

# %%
contenido_lista$Response$View$Result[[1]]$Location$DisplayPosition$Latitude
contenido_lista$Response$View$Result[[1]]$Location$DisplayPosition$Longitude
# Out:
# [1] 37.76665
# [1] -122.4291

# %% [markdown]
# **P2) (2pts)** Identifique los registros de la tabla location, para los cuales los campos `lat` o `lng` **son NA**. Guarde la tabla resultante de la cosulta anterior en un data.frame llamado `location_busqueda`, salvo los ids 6527, 2645, 5991  y 6076, para los cuales no buscaremos su geolocalización.

# %%
location_busqueda <- location %>%
  filter(is.na(lat) | is.na(lng) & !(id_rest %in% c(6527,2645,5991,6076)) )
  
dim(location_busqueda)
summary(location_busqueda)
# Out:
# [1] 504   7
#     id_rest       street_num      street_name            city
#  Min.   :  26   Min.   :    1.0   Length:504         Length:504
#  1st Qu.:2232   1st Qu.:  534.5   Class :character   Class :character
#  Median :4678   Median : 1417.5   Mode  :character   Mode  :character
#  Mean   :4621   Mean   : 3636.7
#  3rd Qu.:6826   3rd Qu.: 2882.5
#  Max.   :9552   Max.   :47071.0
#
#  county_name             lat           lng
#  Length:504         Min.   : NA   Min.   : NA
#  Class :character   1st Qu.: NA   1st Qu.: NA
#  Mode  :character   Median : NA   Median : NA
#                     Mean   :NaN   Mean   :NaN
#                     3rd Qu.: NA   3rd Qu.: NA
#                     Max.   : NA   Max.   : NA
#                     NA's   :504   NA's   :504

# %% [markdown]
# **P3)** Para los ids ubicados anteriormente usted deberá obtener a información de la latitud y longitud mediante la API de HERE.
#
#   * **a) (6pts)** Genere un loop de tipo `for`, que realice las consultas a la API para los restaurants de la tabla `location_busqueda` y obtenga los valores de la latitud y longitud. Para identificar correctamente a cada dirección, considere incluir los siguientes parámetros en la consulta:
#     * `country`: Dejar fijo en "USA"
#     * `state`: Dejar fijo en "CA"
#     * `city`: Se obtiene de la tabla `location_busqueda`,
#     * `county`: Se obtiene de la tabla `location_busqueda`,
#     * `street`: Se obtiene de la tabla `location_busqueda`,
#     * `housenumber`: Se obtiene de la tabla `location_busqueda`<br>
#       **NOTA:** Este loop puede tardar varios minutos, si está trabajando en colab tenga en cuenta no cerrar la pestaña y que no se interrumpa su conexión a interet.
#       **NOTA2:**
#   * **b) (3pts)** Atualice los datos de la tabla `location`, y verifique que la cantidad de filas en la que los campos `lat` o `lng` son igual a NA, son sólo 4.

# %%
summary(location_busqueda)
# Out:
#     id_rest       street_num      street_name            city
#  Min.   :  26   Min.   :    1.0   Length:504         Length:504
#  1st Qu.:2232   1st Qu.:  534.5   Class :character   Class :character
#  Median :4678   Median : 1417.5   Mode  :character   Mode  :character
#  Mean   :4621   Mean   : 3636.7
#  3rd Qu.:6826   3rd Qu.: 2882.5
#  Max.   :9552   Max.   :47071.0
#
#  county_name             lat           lng
#  Length:504         Min.   : NA   Min.   : NA
#  Class :character   1st Qu.: NA   1st Qu.: NA
#  Mode  :character   Median : NA   Median : NA
#                     Mean   :NaN   Mean   :NaN
#                     3rd Qu.: NA   3rd Qu.: NA
#                     Max.   : NA   Max.   : NA
#                     NA's   :504   NA's   :504

# %%
# a)

for(fila in 1:nrow(location_busqueda)){#fila = 494
  print(paste("consultando" ,fila, "de",nrow(location_busqueda)))
  result <- GET(url,
                query = list(country   = "USA",
                             state ="CA",
                             city = location_busqueda$city[fila],
                             county = location_busqueda$county_name[fila],
                             street =location_busqueda$street_name[fila],
                             housenumber = ifelse(is.na(location_busqueda$street_num[fila]),"",location_busqueda$street_num[fila])
                             #  loc = "California"
                )
  )
  texto <- content(result, as = "text")
  contenido_lista <- fromJSON(texto)
  
  counties <-unique(contenido_lista$Response$View$Result[[1]]$Location$Address$County)
  cities <- unique(contenido_lista$Response$View$Result[[1]]$Location$Address$City)
  lat <- unique(contenido_lista$Response$View$Result[[1]]$Location$DisplayPosition$Latitude)
  lon <- unique(contenido_lista$Response$View$Result[[1]]$Location$DisplayPosition$Longitude)

  location_busqueda[fila,"cities"] <- ifelse(is.null(lat),NA,cities)
  location_busqueda[fila,"county"] <- ifelse(is.null(counties[1]),NA,counties[1]) 
  location_busqueda[fila,"lat"] <- ifelse(is.null(lat[1]),NA,lat[1])
  location_busqueda[fila,"lng"] <- ifelse(is.null(lon[1]),NA,lon[1]) 
  location_busqueda[fila,"n_rest"] <-length(lat)
  
  print(location_busqueda[fila,])
}
# Out:
# [1] "consultando 1 de 504"
#   id_rest street_num street_name     city county_name      lat       lng
# 1      26       2922 domingo ave berkeley     Alameda 37.85853 -122.2441
#     cities  county n_rest
# 1 Berkeley Alameda      1
# [1] "consultando 2 de 504"
#   id_rest street_num        street_name          city county_name      lat
# 2      34       3240 castro valley blvd castro valley     Alameda 37.69582
#        lng        cities  county n_rest
# 2 -122.079 Castro Valley Alameda      1
# [1] "consultando 3 de 504"
#   id_rest street_num  street_name    city  county_name      lat       lng
# 3      36       1089 oak grove rd concord Contra Costa 37.95592 -122.0389
#    cities       county n_rest
# 3 Concord Contra Costa      1
# [1] "consultando 4 de 504"
#   id_rest street_num  street_name      city county_name     lat       lng
# 4      95       2310 homestead rd los altos Santa Clara 37.3376 -122.0678
#      cities      county n_rest
# 4 Los Altos Santa Clara      1
# [1] "consultando 5 de 504"
#   id_rest street_num  street_name     city county_name      lat       lng
# 5     103        333 s abbott ave milpitas Santa Clara 37.42552 -121.9142
#     cities      county n_rest
# 5 Milpitas Santa Clara      1
# [1] "consultando 6 de 504"
#   id_rest street_num street_name        city county_name     lat       lng
# 6     105         65  w main ave morgan hill Santa Clara 37.1299 -121.6559
#        cities      county n_rest
# 6 Morgan Hill Santa Clara      1
# [1] "consultando 7 de 504"
#   id_rest street_num street_name city county_name      lat       lng cities
# 7     112        376  soscol ave napa        Napa 38.28843 -122.2749   Napa
#   county n_rest
# 7   Napa      1
# [1] "consultando 8 de 504"
#   id_rest street_num street_name    city county_name      lat       lng  cities
# 8     126       1211 embarcadero oakland     Alameda 37.78806 -122.2515 Oakland
#    county n_rest
# 8 Alameda      1
# [1] "consultando 9 de 504"
#   id_rest street_num          street_name      city county_name      lat
# 9     135        127 town and country vlg palo alto Santa Clara 37.43848
#         lng    cities      county n_rest
# 9 -122.1606 Palo Alto Santa Clara      1
# [1] "consultando 10 de 504"
#    id_rest street_num       street_name          city  county_name     lat
# 10     148        612 contra costa blvd pleasant hill Contra Costa 37.9746
#          lng        cities       county n_rest
# 10 -122.0649 Pleasant Hill Contra Costa      1
# [1] "consultando 11 de 504"
#    id_rest street_num street_name          city   county_name      lat
# 11     173         55   stevenson san francisco San Francisco 37.78955
#          lng        cities        county n_rest
# 11 -122.3996 San Francisco San Francisco      1
# [1] "consultando 12 de 504"
#    id_rest street_num            street_name     city county_name      lat
# 12     192       3758 stevens creek blvd # 9 san jose Santa Clara 37.32309
#          lng   cities      county n_rest
# 12 -121.9676 San Jose Santa Clara      1
# [1] "consultando 13 de 504"
#    id_rest street_num   street_name        city county_name      lat       lng
# 13     216        603 & 605 main st suisun city      Solano 38.23894 -122.0409
#         cities county n_rest
# 13 Suisun City Solano      1
# [1] "consultando 14 de 504"
#    id_rest street_num    street_name    city county_name      lat       lng
# 14     225        250 fairgrounds dr vallejo      Solano 38.12412 -122.2304
#     cities county n_rest
# 14 Vallejo Solano      1
# [1] "consultando 15 de 504"
#    id_rest street_num        street_name          city   county_name      lat
# 15     240        215 west portal avenue san francisco San Francisco 37.73852
#          lng        cities        county n_rest
# 15 -122.4679 San Francisco San Francisco      1
# [1] "consultando 16 de 504"
#    id_rest street_num  street_name          city   county_name      lat
# 16     242         22 hawthorne st san francisco San Francisco 37.78542
#          lng        cities        county n_rest
# 16 -122.3992 San Francisco San Francisco      1
# [1] "consultando 17 de 504"
#    id_rest street_num street_name       city county_name      lat       lng
# 17     289         75   arbor rd. menlo park   San Mateo 37.44138 -122.1788
#        cities    county n_rest
# 17 Menlo Park San Mateo      1
# [1] "consultando 18 de 504"
#    id_rest street_num       street_name      city county_name     lat     lng
# 18     291        751 e. el camino real sunnyvale Santa Clara 37.3583 -122.02
#       cities      county n_rest
# 18 Sunnyvale Santa Clara      1
# [1] "consultando 19 de 504"
#    id_rest street_num       street_name          city county_name      lat
# 19     293        620 lighthouse avenue pacific grove    Monterey 36.62178
#          lng        cities   county n_rest
# 19 -121.9188 Pacific Grove Monterey      1
# [1] "consultando 20 de 504"
#    id_rest street_num street_name          city   county_name      lat
# 20     312        740   sutter st san francisco San Francisco 37.78898
#          lng        cities        county n_rest
# 20 -122.4128 San Francisco San Francisco      1
# [1] "consultando 21 de 504"
#    id_rest street_num      street_name         city  county_name      lat
# 21     317       3800 valley vista rd. walnut creek Contra Costa 37.92407
#          lng       cities       county n_rest
# 21 -121.9969 Walnut Creek Contra Costa      1
# [1] "consultando 22 de 504"
#    id_rest street_num         street_name         city  county_name      lat
# 22     328       1676 n. california blvd. walnut creek Contra Costa 37.90195
#          lng       cities       county n_rest
# 22 -122.0639 Walnut Creek Contra Costa      1
# [1] "consultando 23 de 504"
#    id_rest street_num  street_name     city county_name      lat       lng
# 23     369       2895 s bascom ave campbell Santa Clara 37.26963 -121.9384
#      cities      county n_rest
# 23 Campbell Santa Clara      1
# [1] "consultando 24 de 504"
#    id_rest street_num   street_name      city county_name      lat       lng
# 24     395        649 san mateo ave san bruno   San Mateo 37.62741 -122.4115
#       cities    county n_rest
# 24 San Bruno San Mateo      1
# [1] "consultando 25 de 504"
#    id_rest street_num street_name       city county_name      lat      lng
# 25     397       1195   laurel st san carlos   San Mateo 37.49904 -122.252
#        cities    county n_rest
# 25 San Carlos San Mateo      1
# [1] "consultando 26 de 504"
#    id_rest street_num      street_name     city county_name      lat       lng
# 26     401       1006 e santa clara st san jose Santa Clara 37.34555 -121.8701
#      cities      county n_rest
# 26 San Jose Santa Clara      1
# [1] "consultando 27 de 504"
#    id_rest street_num     street_name     city county_name      lat       lng
# 27     408        457 e san carlos st san jose Santa Clara 37.33641 -121.8773
#      cities      county n_rest
# 27 San Jose Santa Clara      1
# [1] "consultando 28 de 504"
#    id_rest street_num      street_name      city county_name      lat      lng
# 28     429       2456 s el camino real san mateo   San Mateo 37.54435 -122.306
#       cities    county n_rest
# 28 San Mateo San Mateo      1
# [1] "consultando 29 de 504"
#    id_rest street_num       street_name        city county_name      lat
# 29     430        500 lawrence expy # c santa clara Santa Clara 37.33171
#          lng      cities      county n_rest
# 29 -121.9959 Santa Clara Santa Clara      1
# [1] "consultando 30 de 504"
#    id_rest street_num    street_name        city county_name      lat       lng
# 30     453       1205 el camino real santa clara Santa Clara 37.35368 -121.9498
#         cities      county n_rest
# 30 Santa Clara Santa Clara      1
# [1] "consultando 31 de 504"
#    id_rest street_num street_name          city   county_name      lat
# 31     459       1475     polk st san francisco San Francisco 37.79028
#          lng        cities        county n_rest
# 31 -122.4209 San Francisco San Francisco      1
# [1] "consultando 32 de 504"
#    id_rest street_num street_name      city county_name      lat       lng
# 32     463        637   so. b st. san mateo   San Mateo 37.56296 -122.3194
#       cities    county n_rest
# 32 San Mateo San Mateo      1
# [1] "consultando 33 de 504"
#    id_rest street_num street_name     city county_name      lat      lng
# 33     525        271 e brokaw rd san jose Santa Clara 37.37741 -121.914
#      cities      county n_rest
# 33 San Jose Santa Clara      1
# [1] "consultando 34 de 504"
#    id_rest street_num  street_name     city county_name      lat       lng
# 34     568       2181 shattuck ave berkeley     Alameda 37.86983 -122.2675
#      cities  county n_rest
# 34 Berkeley Alameda      1
# [1] "consultando 35 de 504"
#    id_rest street_num    street_name     city county_name      lat       lng
# 35     569       1310 university ave berkeley     Alameda 37.86934 -122.2862
#      cities  county n_rest
# 35 Berkeley Alameda      1
# [1] "consultando 36 de 504"
#    id_rest street_num street_name      city county_name      lat       lng
# 36     613        833    texas st fairfield      Solano 38.24887 -122.0441
#       cities county n_rest
# 36 Fairfield Solano      1
# [1] "consultando 37 de 504"
#    id_rest street_num street_name      city county_name      lat       lng
# 37     643        201      5th st hollister  San Benito 36.85113 -121.4012
#       cities     county n_rest
# 37 Hollister San Benito      1
# [1] "consultando 38 de 504"
#    id_rest street_num street_name city county_name      lat       lng cities
# 38     660       3385  calif blvd napa        Napa 38.29911 -122.2854   Napa
#    county n_rest
# 38   Napa      1
# [1] "consultando 39 de 504"
#    id_rest street_num street_name   city county_name     lat      lng cities
# 39     668      37013      ash st newark     Alameda 37.5289 -122.041 Newark
#     county n_rest
# 39 Alameda      1
# [1] "consultando 40 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 40     679        266     14th st oakland     Alameda 37.80285 -122.2668
#     cities  county n_rest
# 40 Oakland Alameda      1
# [1] "consultando 41 de 504"
#    id_rest street_num    street_name    city county_name      lat       lng
# 41     680       3000 macarthur blvd oakland     Alameda 37.79742 -122.2046
#     cities  county n_rest
# 41 Oakland Alameda      1
# [1] "consultando 42 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 42     707        355     19th st oakland     Alameda 37.80663 -122.2668
#     cities  county n_rest
# 42 Oakland Alameda      1
# [1] "consultando 43 de 504"
#    id_rest street_num street_name       city county_name      lat       lng
# 43     725        122   w neal st pleasanton     Alameda 37.66008 -121.8753
#        cities  county n_rest
# 43 Pleasanton Alameda      1
# [1] "consultando 44 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 44     812       1817  capitol st vallejo      Solano 38.10261 -122.2375
#     cities county n_rest
# 44 Vallejo Solano      1
# [1] "consultando 45 de 504"
#    id_rest street_num street_name         city  county_name      lat       lng
# 45     820       2112   n main st walnut creek Contra Costa 37.90882 -122.0644
#          cities       county n_rest
# 45 Walnut Creek Contra Costa      1
# [1] "consultando 46 de 504"
#    id_rest street_num street_name  city county_name      lat       lng cities
# 46     826        100    s 1st st dixon      Solano 38.44541 -121.8228  Dixon
#    county n_rest
# 46 Solano      1
# [1] "consultando 47 de 504"
#    id_rest street_num street_name       city county_name      lat       lng
# 47     843       2700  yulupa ave santa rosa      Sonoma 38.42768 -122.6679
#        cities county n_rest
# 47 Santa Rosa Sonoma      1
# [1] "consultando 48 de 504"
#    id_rest street_num       street_name       city county_name      lat
# 48     845         19 old courthouse sq santa rosa      Sonoma 38.43956
#          lng     cities county n_rest
# 48 -122.7143 Santa Rosa Sonoma      1
# [1] "consultando 49 de 504"
#    id_rest street_num street_name          city   county_name      lat
# 49     870        630  sansome st san francisco San Francisco 37.79623
#          lng        cities        county n_rest
# 49 -122.4014 San Francisco San Francisco      1
# [1] "consultando 50 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 50     928        300        a st hayward     Alameda 37.66868 -122.0959
#     cities  county n_rest
# 50 Hayward Alameda      1
# [1] "consultando 51 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 51     940      10135   pippin st oakland     Alameda 37.73665 -122.1782
#     cities  county n_rest
# 51 Oakland Alameda      1
# [1] "consultando 52 de 504"
#    id_rest street_num  street_name     city county_name      lat       lng
# 52     951        491 saratoga ave san jose Santa Clara 37.31873 -121.9739
#      cities      county n_rest
# 52 San Jose Santa Clara      1
# [1] "consultando 53 de 504"
#    id_rest street_num  street_name     city county_name      lat       lng
# 53     960       1110 s bascom ave san jose Santa Clara 37.30601 -121.9311
#      cities      county n_rest
# 53 San Jose Santa Clara      1
# [1] "consultando 54 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 54     969        410   west a st hayward     Alameda 37.66565 -122.1082
#     cities  county n_rest
# 54 Hayward Alameda      1
# [1] "consultando 55 de 504"
#    id_rest street_num street_name     city county_name      lat       lng
# 55    1032       3201 college ave berkeley     Alameda 37.85141 -122.2523
#      cities  county n_rest
# 55 Berkeley Alameda      1
# [1] "consultando 56 de 504"
#    id_rest street_num street_name       city county_name      lat       lng
# 56    1059        909    ocean st santa cruz  Santa Cruz 36.98039 -122.0219
#        cities     county n_rest
# 56 Santa Cruz Santa Cruz      1
# [1] "consultando 57 de 504"
#    id_rest street_num street_name       city county_name      lat       lng
# 57    1060       1711  mission st santa cruz  Santa Cruz 36.96505 -122.0415
#        cities     county n_rest
# 57 Santa Cruz Santa Cruz      1
# [1] "consultando 58 de 504"
#    id_rest street_num street_name      city county_name      lat       lng
# 58    1062        439  molino ave sunnyvale Santa Clara 37.37393 -122.0471
#       cities      county n_rest
# 58 Sunnyvale Santa Clara      1
# [1] "consultando 59 de 504"
#    id_rest street_num street_name    city  county_name      lat       lng
# 59    1113       1115   e 18th st antioch Contra Costa 38.00436 -121.7866
#     cities       county n_rest
# 59 Antioch Contra Costa      1
# [1] "consultando 60 de 504"
#    id_rest street_num street_name     city county_name      lat       lng
# 60    1119       2505  dwight way berkeley     Alameda 37.86541 -122.2582
#      cities  county n_rest
# 60 Berkeley Alameda      1
# [1] "consultando 61 de 504"
#    id_rest street_num   street_name     city county_name      lat       lng
# 61    1123       1775 san pablo ave berkeley     Alameda 37.87197 -122.2927
#      cities  county n_rest
# 61 Berkeley Alameda      1
# [1] "consultando 62 de 504"
#    id_rest street_num  street_name    city county_name      lat     lng  cities
# 62    1169      39020 argonaut way fremont     Alameda 37.54573 -121.99 Fremont
#     county n_rest
# 62 Alameda      1
# [1] "consultando 63 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 63    1199       1235        a st hayward     Alameda 37.67663 -122.0795
#     cities  county n_rest
# 63 Hayward Alameda      1
# [1] "consultando 64 de 504"
#    id_rest street_num           street_name      city  county_name      lat
# 64    1205       3508 mount diablo blvd # j lafayette Contra Costa 37.89246
#          lng    cities       county n_rest
# 64 -122.1171 Lafayette Contra Costa      1
# [1] "consultando 65 de 504"
#    id_rest street_num street_name   city county_name     lat       lng cities
# 65    1229       5450 newpark plz newark     Alameda 37.5225 -121.9999 Newark
#     county n_rest
# 65 Alameda      1
# [1] "consultando 66 de 504"
#    id_rest street_num   street_name    city county_name     lat       lng
# 66    1233       5325 san pablo ave oakland     Alameda 37.8376 -122.2823
#     cities  county n_rest
# 66 Oakland Alameda      1
# [1] "consultando 67 de 504"
#    id_rest street_num street_name    city county_name      lat      lng  cities
# 67    1239       4610   e 14th st oakland     Alameda 37.77092 -122.211 Oakland
#     county n_rest
# 67 Alameda      1
# [1] "consultando 68 de 504"
#    id_rest street_num    street_name    city county_name     lat       lng
# 68    1243       7200 san leandro st oakland     Alameda 37.7536 -122.1967
#     cities  county n_rest
# 68 Oakland Alameda      1
# [1] "consultando 69 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 69    1247        949 w grand ave oakland     Alameda 37.81397 -122.2795
#     cities  county n_rest
# 69 Oakland Alameda      1
# [1] "consultando 70 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 70    1261       5925 college ave oakland     Alameda 37.84761 -122.2523
#     cities  county n_rest
# 70 Oakland Alameda      1
# [1] "consultando 71 de 504"
#    id_rest street_num street_name  city  county_name      lat       lng cities
# 71    1305        358  parker ave rodeo Contra Costa 38.03365 -122.2676  Rodeo
#          county n_rest
# 71 Contra Costa      1
# [1] "consultando 72 de 504"
#    id_rest street_num     street_name     city county_name      lat       lng
# 72    1317       1349 blossom hill rd san jose Santa Clara 37.24641 -121.8869
#      cities      county n_rest
# 72 San Jose Santa Clara      1
# [1] "consultando 73 de 504"
#    id_rest street_num     street_name     city county_name      lat       lng
# 73    1320        120 blossom hill rd san jose Santa Clara 37.25258 -121.8061
#      cities      county n_rest
# 73 San Jose Santa Clara      1
# [1] "consultando 74 de 504"
#    id_rest street_num  street_name     city county_name      lat       lng
# 74    1340        782 s bascom ave san jose Santa Clara 37.31308 -121.9311
#      cities      county n_rest
# 74 San Jose Santa Clara      1
# [1] "consultando 75 de 504"
#    id_rest street_num street_name        city county_name      lat       lng
# 75    1342      14345   acacia st san leandro     Alameda 37.70101 -122.1602
#         cities  county n_rest
# 75 San Leandro Alameda      1
# [1] "consultando 76 de 504"
#    id_rest street_num    street_name        city county_name      lat       lng
# 76    1345       1335 washington ave san leandro     Alameda 37.72395 -122.1566
#         cities  county n_rest
# 76 San Leandro Alameda      1
# [1] "consultando 77 de 504"
#    id_rest street_num      street_name        city county_name      lat
# 77    1356       1133 san leandro blvd san leandro     Alameda 37.72445
#          lng      cities  county n_rest
# 77 -122.1622 San Leandro Alameda      1
# [1] "consultando 78 de 504"
#    id_rest street_num    street_name        city county_name      lat       lng
# 78    1365      15600 hesperian blvd san lorenzo     Alameda 37.68693 -122.1296
#         cities  county n_rest
# 78 San Lorenzo Alameda      1
# [1] "consultando 79 de 504"
#    id_rest street_num      street_name      city county_name      lat       lng
# 79    1368       2700 s el camino real san mateo   San Mateo 37.54224 -122.3038
#       cities    county n_rest
# 79 San Mateo San Mateo      1
# [1] "consultando 80 de 504"
#    id_rest street_num  street_name      city  county_name      lat      lng
# 80    1372       1789 rumrill blvd san pablo Contra Costa 37.95857 -122.357
#       cities       county n_rest
# 80 San Pablo Contra Costa      1
# [1] "consultando 81 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 81    1426       2525 sonoma blvd vallejo      Solano 38.10972 -122.2551
#     cities county n_rest
# 81 Vallejo Solano      1
# [1] "consultando 82 de 504"
#    id_rest street_num street_name    city county_name      lat      lng  cities
# 82    1427         25   rancho sq vallejo      Solano 38.15463 -122.255 Vallejo
#    county n_rest
# 82 Solano      1
# [1] "consultando 83 de 504"
#    id_rest street_num street_name          city   county_name      lat
# 83    1430       3991          st san francisco San Francisco 37.72606
#          lng        cities        county n_rest
# 83 -122.4783 San Francisco San Francisco      1
# [1] "consultando 84 de 504"
#    id_rest street_num     street_name     city county_name      lat       lng
# 84    1449        576 linda mar blvd. pacifica   San Mateo 37.59425 -122.5037
#      cities    county n_rest
# 84 Pacifica San Mateo      1
# [1] "consultando 85 de 504"
#    id_rest street_num   street_name    city county_name      lat       lng
# 85    1462        875 island dr # d alameda     Alameda 37.73752 -122.2389
#     cities  county n_rest
# 85 Alameda Alameda      1
# [1] "consultando 86 de 504"
#    id_rest street_num      street_name    city county_name     lat       lng
# 86    1464        883 b-2 island drive alameda     Alameda 37.7375 -122.2389
#     cities  county n_rest
# 86 Alameda Alameda      1
# [1] "consultando 87 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 87    1468       1506     park st alameda     Alameda 37.76555 -122.2414
#     cities  county n_rest
# 87 Alameda Alameda      1
# [1] "consultando 88 de 504"
#    id_rest street_num  street_name     city county_name      lat       lng
# 88    1510       1730 shattuck ave berkeley     Alameda 37.87595 -122.2691
#      cities  county n_rest
# 88 Berkeley Alameda      1
# [1] "consultando 89 de 504"
#    id_rest street_num street_name     city county_name      lat      lng
# 89    1542       2128      center berkeley     Alameda 37.87015 -122.267
#      cities  county n_rest
# 89 Berkeley Alameda      1
# [1] "consultando 90 de 504"
#    id_rest street_num        street_name     city county_name      lat
# 90    1589        100 w hamilton ave # b campbell Santa Clara 37.29376
#          lng   cities      county n_rest
# 90 -121.9519 Campbell Santa Clara      1
# [1] "consultando 91 de 504"
#    id_rest street_num                 street_name     city  county_name
# 91    1643        145 town and country dr ste 104 danville Contra Costa
#         lat       lng   cities       county n_rest
# 91 37.81339 -121.9996 Danville Contra Costa      1
# [1] "consultando 92 de 504"
#    id_rest street_num          street_name   city county_name      lat
# 92    1649      11875 dublin blvd ste c150 dublin     Alameda 37.70109
#          lng cities  county n_rest
# 92 -121.9379 Dublin Alameda      1
# [1] "consultando 93 de 504"
#    id_rest street_num street_name       city county_name      lat       lng
# 93    1659       4240   hollis st emeryville     Alameda 37.83258 -122.2861
#        cities  county n_rest
# 93 Emeryville Alameda      1
# [1] "consultando 94 de 504"
#    id_rest street_num street_name      city county_name     lat       lng
# 94    1672        740    texas st fairfield      Solano 38.2495 -122.0426
#       cities county n_rest
# 94 Fairfield Solano      1
# [1] "consultando 95 de 504"
#    id_rest street_num street_name      city county_name      lat       lng
# 95    1673       1123    texas st fairfield      Solano 38.24912 -122.0475
#       cities county n_rest
# 95 Fairfield Solano      1
# [1] "consultando 96 de 504"
#    id_rest street_num street_name    city county_name      lat       lng
# 96    1687         50  whitney pl fremont     Alameda 37.46977 -121.9186
#     cities  county n_rest
# 96 Fremont Alameda      1
# [1] "consultando 97 de 504"
#    id_rest street_num street_name    city county_name      lat      lng  cities
# 97    1710      47071 bayside pky fremont     Alameda 37.47639 -121.939 Fremont
#     county n_rest
# 97 Alameda      1
# [1] "consultando 98 de 504"
#    id_rest street_num street_name      city  county_name      lat       lng
# 98    1758        998   moraga rd lafayette Contra Costa 37.89163 -122.1186
#       cities       county n_rest
# 98 Lafayette Contra Costa      1
# [1] "consultando 99 de 504"
#    id_rest street_num street_name      city county_name      lat       lng
# 99    1769        296     main st los altos Santa Clara 37.37859 -122.1168
#       cities      county n_rest
# 99 Los Altos Santa Clara      1
# [1] "consultando 100 de 504"
#     id_rest street_num         street_name      city county_name      lat
# 100    1780      14103 winchester blvd # c los gatos Santa Clara 37.26251
#           lng    cities      county n_rest
# 100 -121.9623 Los Gatos Santa Clara      1
# [1] "consultando 101 de 504"
#     id_rest street_num   street_name      city county_name      lat       lng
# 101    1787      14685 oka rd lot 62 los gatos Santa Clara 37.25566 -121.9603
#        cities      county n_rest
# 101 Los Gatos Santa Clara      1
# [1] "consultando 102 de 504"
#     id_rest street_num street_name     city  county_name      lat       lng
# 102    1790        533     main st martinez Contra Costa 38.01697 -122.1378
#       cities       county n_rest
# 102 Martinez Contra Costa      1
# [1] "consultando 103 de 504"
#     id_rest street_num street_name     city  county_name      lat      lng
# 103    1791        811    ferry st martinez Contra Costa 38.01703 -122.135
#       cities       county n_rest
# 103 Martinez Contra Costa      1
# [1] "consultando 104 de 504"
#     id_rest street_num    street_name     city county_name      lat       lng
# 104    1805          9 hillcrest blvd millbrae   San Mateo 37.60185 -122.3919
#       cities    county n_rest
# 104 Millbrae San Mateo      1
# [1] "consultando 105 de 504"
#     id_rest street_num             street_name     city county_name      lat
# 105    1814       1350 s park victoria dr # 27 milpitas Santa Clara 37.41758
#           lng   cities      county n_rest
# 105 -121.8744 Milpitas Santa Clara      1
# [1] "consultando 106 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 106    1873       1437    23rd ave oakland     Alameda 37.78412 -122.2357
#      cities  county n_rest
# 106 Oakland Alameda      1
# [1] "consultando 107 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 107    1879        812 franklin st oakland     Alameda 37.79991 -122.2721
#      cities  county n_rest
# 107 Oakland Alameda      1
# [1] "consultando 108 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 108    1898        446   e 12th st oakland     Alameda 37.79545 -122.2548
#      cities  county n_rest
# 108 Oakland Alameda      1
# [1] "consultando 109 de 504"
#     id_rest street_num street_name   city  county_name      lat       lng
# 109    1937         87  orinda way orinda Contra Costa 37.88548 -122.1924
#     cities       county n_rest
# 109 Orinda Contra Costa      1
# [1] "consultando 110 de 504"
#     id_rest street_num    street_name      city county_name     lat       lng
# 110    1955       3191 middlefield rd palo alto Santa Clara 37.4296 -122.1227
#        cities      county n_rest
# 110 Palo Alto Santa Clara      1
# [1] "consultando 111 de 504"
#     id_rest street_num         street_name       city county_name      lat
# 111    1982       1987 santa rita rd ste h pleasanton     Alameda 37.67898
#           lng     cities  county n_rest
# 111 -121.8757 Pleasanton Alameda      1
# [1] "consultando 112 de 504"
#     id_rest street_num street_name         city county_name     lat       lng
# 112    2019       2655    broadway redwood city   San Mateo 37.4861 -122.2342
#           cities    county n_rest
# 112 Redwood City San Mateo      1
# [1] "consultando 113 de 504"
#     id_rest street_num street_name     city  county_name      lat       lng
# 113    2027        109     park pl richmond Contra Costa 37.92681 -122.3847
#       cities       county n_rest
# 113 Richmond Contra Costa      1
# [1] "consultando 114 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 114    2075        138      church san francisco San Francisco 37.76872
#           lng        cities        county n_rest
# 114 -122.4294 San Francisco San Francisco      1
# [1] "consultando 115 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 115    2124       2700    n 1st st san jose Santa Clara 37.39015 -121.9293
#       cities      county n_rest
# 115 San Jose Santa Clara      1
# [1] "consultando 116 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 116    2129       2062 curtner ave san jose Santa Clara 37.27207 -121.9337
#       cities      county n_rest
# 116 San Jose Santa Clara      1
# [1] "consultando 117 de 504"
#     id_rest street_num       street_name     city county_name      lat
# 117    2148       1758 junction ave # 1a san jose Santa Clara 37.37727
#           lng   cities      county n_rest
# 117 -121.9053 San Jose Santa Clara      1
# [1] "consultando 118 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 118    2155       3975   senter rd san jose Santa Clara 37.28343 -121.8243
#       cities      county n_rest
# 118 San Jose Santa Clara      1
# [1] "consultando 119 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 119    2169       1441    n 4th st san jose Santa Clara 37.36386 -121.9078
#       cities      county n_rest
# 119 San Jose Santa Clara      1
# [1] "consultando 120 de 504"
#     id_rest street_num  street_name     city county_name      lat       lng
# 120    2171       2208 business cir san jose Santa Clara 37.32235 -121.9324
#       cities      county n_rest
# 120 San Jose Santa Clara      1
# [1] "consultando 121 de 504"
#     id_rest street_num       street_name     city county_name      lat
# 121    2184       7170 santa teresa blvd san jose Santa Clara 37.22583
#           lng   cities      county n_rest
# 121 -121.7741 San Jose Santa Clara      2
# [1] "consultando 122 de 504"
#     id_rest street_num       street_name     city county_name      lat
# 122    2189       7028 santa teresa blvd san jose Santa Clara 37.22756
#           lng   cities      county n_rest
# 122 -121.7758 San Jose Santa Clara      1
# [1] "consultando 123 de 504"
#     id_rest street_num  street_name     city county_name      lat       lng
# 123    2192       1385 cabrillo ave san jose Santa Clara 37.39428 -121.8673
#       cities      county n_rest
# 123 San Jose Santa Clara      1
# [1] "consultando 124 de 504"
#     id_rest street_num              street_name      city county_name      lat
# 124    2246        400 s el camino real ste 125 san mateo   San Mateo 37.56188
#           lng    cities    county n_rest
# 124 -122.3252 San Mateo San Mateo      1
# [1] "consultando 125 de 504"
#     id_rest street_num  street_name        city county_name      lat       lng
# 125    2271       2605 homestead rd santa clara Santa Clara 37.33979 -121.9727
#          cities      county n_rest
# 125 Santa Clara Santa Clara      1
# [1] "consultando 126 de 504"
#     id_rest street_num   street_name        city county_name      lat       lng
# 126    2278         57 washington st santa clara Santa Clara 37.33924 -121.9385
#          cities      county n_rest
# 126 Santa Clara Santa Clara      1
# [1] "consultando 127 de 504"
#     id_rest street_num street_name       city county_name      lat       lng
# 127    2288       1410  mission st santa cruz  Santa Cruz 36.96758 -122.0393
#         cities     county n_rest
# 127 Santa Cruz Santa Cruz      1
# [1] "consultando 128 de 504"
#     id_rest street_num street_name       city county_name      lat      lng
# 128    2305        334    swift st santa cruz  Santa Cruz 36.95493 -122.048
#         cities     county n_rest
# 128 Santa Cruz Santa Cruz      1
# [1] "consultando 129 de 504"
#     id_rest street_num     street_name      city county_name      lat       lng
# 129    2318        550 lakeside dr # 1 sunnyvale Santa Clara 37.38588 -121.9929
#        cities      county n_rest
# 129 Sunnyvale Santa Clara      1
# [1] "consultando 130 de 504"
#     id_rest street_num  street_name    city county_name      lat       lng
# 130    2348       1030 tennessee st vallejo      Solano 38.11019 -122.2454
#      cities county n_rest
# 130 Vallejo Solano      1
# [1] "consultando 131 de 504"
#     id_rest street_num street_name         city  county_name      lat       lng
# 131    2370       1655   n main st walnut creek Contra Costa 37.90109 -122.0619
#           cities       county n_rest
# 131 Walnut Creek Contra Costa      1
# [1] "consultando 132 de 504"
#     id_rest street_num     street_name     city county_name      lat       lng
# 132    2406        201 e washington st petaluma      Sonoma 38.23695 -122.6381
#       cities county n_rest
# 132 Petaluma Sonoma      1
# [1] "consultando 133 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 133    2408        220 western ave petaluma      Sonoma 38.23348 -122.6424
#       cities county n_rest
# 133 Petaluma Sonoma      1
# [1] "consultando 134 de 504"
#     id_rest street_num     street_name     city county_name      lat       lng
# 134    2412         17 petaluma blvd n petaluma      Sonoma 38.23321 -122.6402
#       cities county n_rest
# 134 Petaluma Sonoma      1
# [1] "consultando 135 de 504"
#     id_rest street_num street_name       city county_name     lat       lng
# 135    2459        443  dutton ave santa rosa      Sonoma 38.4312 -122.7263
#         cities county n_rest
# 135 Santa Rosa Sonoma      1
# [1] "consultando 136 de 504"
#     id_rest street_num street_name       city county_name      lat       lng
# 136    2464        128   n main st sebastopol      Sonoma 38.40242 -122.8246
#         cities county n_rest
# 136 Sebastopol Sonoma      1
# [1] "consultando 137 de 504"
#     id_rest street_num street_name   city county_name      lat       lng cities
# 137    2472      18140  sonoma hwy sonoma      Sonoma 38.31304 -122.4824 Sonoma
#     county n_rest
# 137 Sonoma      1
# [1] "consultando 138 de 504"
#     id_rest street_num                      street_name    city county_name
# 138    2535         30 jack london sq (jlondon village) oakland     Alameda
#          lat       lng  cities  county n_rest
# 138 37.79481 -122.2769 Oakland Alameda      1
# [1] "consultando 139 de 504"
#     id_rest street_num      street_name     city county_name      lat       lng
# 139    2549         88 north hill drive brisbane   San Mateo 37.68885 -122.4105
#       cities    county n_rest
# 139 Brisbane San Mateo      1
# [1] "consultando 140 de 504"
#     id_rest street_num street_name   city  county_name      lat       lng
# 140    2576       1600 st. andrews moraga Contra Costa 37.83585 -122.1366
#     cities       county n_rest
# 140 Moraga Contra Costa      1
# [1] "consultando 141 de 504"
#     id_rest street_num street_name      city county_name      lat       lng
# 141    2584          1             davenport  Santa Cruz 37.01135 -122.1954
#        cities     county n_rest
# 141 Davenport Santa Cruz      1
# [1] "consultando 142 de 504"
#     id_rest street_num street_name       city county_name      lat       lng
# 142    2605        405    main st. pleasanton     Alameda 37.65973 -121.8766
#         cities  county n_rest
# 142 Pleasanton Alameda      1
# [1] "consultando 143 de 504"
#     id_rest street_num      street_name          city   county_name      lat
# 143    2613       1500 mission (duboce) san francisco San Francisco 37.77428
#           lng        cities        county n_rest
# 143 -122.4176 San Francisco San Francisco      1
# [1] "consultando 144 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 144    2680       1769     lombard san francisco San Francisco 37.80025
#           lng        cities        county n_rest
# 144 -122.4305 San Francisco San Francisco      1
# [1] "consultando 145 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 145    2683       4217  geary blvd san francisco San Francisco 37.78069
#           lng        cities        county n_rest
# 145 -122.4646 San Francisco San Francisco      1
# [1] "consultando 146 de 504"
#     id_rest street_num  street_name      city county_name      lat       lng
# 146    2690        455 hamilton ave palo alto Santa Clara 37.44721 -122.1584
#        cities      county n_rest
# 146 Palo Alto Santa Clara      1
# [1] "consultando 147 de 504"
#     id_rest street_num           street_name     city  county_name      lat
# 147    2716        569 san ramon valley blvd danville Contra Costa 37.81587
#           lng   cities       county n_rest
# 147 -121.9967 Danville Contra Costa      1
# [1] "consultando 148 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 148    2731       1798  catalpa ct hayward     Alameda 37.62212 -122.0803
#      cities  county n_rest
# 148 Hayward Alameda      1
# [1] "consultando 149 de 504"
#     id_rest street_num       street_name     city county_name      lat
# 149    2749       1425 calle oriente # 3 milpitas Santa Clara 37.44713
#           lng   cities      county n_rest
# 149 -121.8848 Milpitas Santa Clara      1
# [1] "consultando 150 de 504"
#     id_rest street_num    street_name         city county_name      lat
# 150    2791       1059 wilmington way redwood city   San Mateo 37.45489
#           lng       cities    county n_rest
# 150 -122.2623 Redwood City San Mateo      1
# [1] "consultando 151 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 151    2806       1500  almaden rd san jose Santa Clara 37.31063 -121.8771
#       cities      county n_rest
# 151 San Jose Santa Clara      1
# [1] "consultando 152 de 504"
#     id_rest street_num  street_name      city county_name      lat       lng
# 152    2816        863 woodside way san mateo   San Mateo 37.57781 -122.3372
#        cities    county n_rest
# 152 San Mateo San Mateo      1
# [1] "consultando 153 de 504"
#     id_rest street_num street_name        city county_name      lat      lng
# 153    2841      11251  skyline rd forestville      Sonoma 38.51262 -122.931
#          cities county n_rest
# 153 Forestville Sonoma      1
# [1] "consultando 154 de 504"
#     id_rest street_num     street_name     city county_name      lat       lng
# 154    2842       1390 n mcdowell blvd petaluma      Sonoma 38.27616 -122.6676
#       cities county n_rest
# 154 Petaluma Sonoma      1
# [1] "consultando 155 de 504"
#     id_rest street_num street_name       city county_name      lat       lng
# 155    2856        340 yolanda ave santa rosa      Sonoma 38.41308 -122.7116
#         cities county n_rest
# 155 Santa Rosa Sonoma      1
# [1] "consultando 156 de 504"
#     id_rest street_num street_name        city county_name      lat       lng
# 156    2900       2026    agnew rd santa clara Santa Clara 37.39436 -121.9597
#          cities      county n_rest
# 156 Santa Clara Santa Clara      1
# [1] "consultando 157 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 157    2910       2564  springs rd vallejo      Solano 38.10619 -122.2097
#      cities county n_rest
# 157 Vallejo Solano      1
# [1] "consultando 158 de 504"
#     id_rest street_num    street_name    city county_name      lat       lng
# 158    2932        642 lincoln avenue alameda     Alameda 37.77505 -122.2772
#      cities  county n_rest
# 158 Alameda Alameda      1
# [1] "consultando 159 de 504"
#     id_rest street_num street_name         city  county_name      lat       lng
# 159    3022       1627      n. brd walnut creek Contra Costa 37.90162 -122.0619
#           cities       county n_rest
# 159 Walnut Creek Contra Costa      1
# [1] "consultando 160 de 504"
#     id_rest street_num street_name    city  county_name     lat       lng
# 160    3024       1980  galindo st concord Contra Costa 37.9767 -122.0356
#      cities       county n_rest
# 160 Concord Contra Costa      1
# [1] "consultando 161 de 504"
#     id_rest street_num        street_name      city county_name      lat
# 161    3053      19740 stevens creek blvd cupertino Santa Clara 37.32209
#           lng    cities      county n_rest
# 161 -122.0179 Cupertino Santa Clara      1
# [1] "consultando 162 de 504"
#     id_rest street_num street_name       city county_name     lat       lng
# 162    3084       3986  adeline st emeryville     Alameda 37.8308 -122.2782
#         cities  county n_rest
# 162 Emeryville Alameda      1
# [1] "consultando 163 de 504"
#     id_rest street_num street_name      city county_name      lat       lng
# 163    3097       2155  n texas st fairfield      Solano 38.26862 -122.0343
#        cities county n_rest
# 163 Fairfield Solano      1
# [1] "consultando 164 de 504"
#     id_rest street_num  street_name    city county_name      lat      lng
# 164    3106        225 carnation dr freedom  Santa Cruz 36.93636 -121.769
#      cities     county n_rest
# 164 Freedom Santa Cruz      1
# [1] "consultando 165 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 165    3112        681   mowry ave fremont     Alameda 37.56695 -121.9743
#      cities  county n_rest
# 165 Fremont Alameda      1
# [1] "consultando 166 de 504"
#     id_rest street_num  street_name    city county_name      lat       lng
# 166    3118      39060 fremont blvd fremont     Alameda 37.54861 -121.9869
#      cities  county n_rest
# 166 Fremont Alameda      1
# [1] "consultando 167 de 504"
#     id_rest street_num        street_name    city county_name      lat
# 167    3124      34460 fremont blvd ste b fremont     Alameda 37.57509
#           lng  cities  county n_rest
# 167 -122.0386 Fremont Alameda      1
# [1] "consultando 168 de 504"
#     id_rest street_num street_name    city county_name     lat       lng
# 168    3128      39139  farwell dr fremont     Alameda 37.5321 -121.9988
#      cities  county n_rest
# 168 Fremont Alameda      1
# [1] "consultando 169 de 504"
#     id_rest street_num   street_name    city county_name      lat       lng
# 169    3154      22545 foothill blvd hayward     Alameda 37.67439 -122.0816
#      cities  county n_rest
# 169 Hayward Alameda      1
# [1] "consultando 170 de 504"
#     id_rest street_num street_name   city  county_name   lat       lng cities
# 170    3222        380     park st moraga Contra Costa 37.86 -122.1256 Moraga
#           county n_rest
# 170 Contra Costa      1
# [1] "consultando 171 de 504"
#     id_rest street_num  street_name city county_name      lat       lng cities
# 171    3250       2985 jefferson st napa        Napa 38.31512 -122.2986   Napa
#     county n_rest
# 171   Napa      1
# [1] "consultando 172 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 172    3260       1698      7th st oakland     Alameda 37.80682 -122.3007
#      cities  county n_rest
# 172 Oakland Alameda      1
# [1] "consultando 173 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 173    3267       1614   castro st oakland     Alameda 37.80824 -122.2758
#      cities  county n_rest
# 173 Oakland Alameda      1
# [1] "consultando 174 de 504"
#     id_rest street_num    street_name    city county_name      lat      lng
# 174    3300       2531 macarthur blvd oakland     Alameda 37.79918 -122.212
#      cities  county n_rest
# 174 Oakland Alameda      1
# [1] "consultando 175 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 175    3322       3601   grand ave oakland     Alameda 37.81517 -122.2463
#      cities  county n_rest
# 175 Oakland Alameda      1
# [1] "consultando 176 de 504"
#     id_rest street_num   street_name    city county_name      lat       lng
# 176    3323       6465 san pablo ave oakland     Alameda 37.84769 -122.2856
#      cities  county n_rest
# 176 Oakland Alameda      1
# [1] "consultando 177 de 504"
#     id_rest street_num street_name    city county_name     lat       lng
# 177    3335        835  webster st oakland     Alameda 37.7996 -122.2713
#      cities  county n_rest
# 177 Oakland Alameda      1
# [1] "consultando 178 de 504"
#     id_rest street_num street_name    city county_name      lat      lng
# 178    3348        723   e 12th st oakland     Alameda 37.79305 -122.253
#      cities  county n_rest
# 178 Oakland Alameda      1
# [1] "consultando 179 de 504"
#     id_rest street_num  street_name    city  county_name      lat       lng
# 179    3366       5867 pacheco blvd pacheco Contra Costa 37.98324 -122.0671
#       cities       county n_rest
# 179 Martinez Contra Costa      1
# [1] "consultando 180 de 504"
#     id_rest street_num      street_name          city  county_name      lat
# 180    3393       2653 pleasant hill rd pleasant hill Contra Costa 37.95426
#           lng        cities       county n_rest
# 180 -122.0896 Pleasant Hill Contra Costa      1
# [1] "consultando 181 de 504"
#     id_rest street_num   street_name          city  county_name      lat
# 181    3397       2290 monument blvd pleasant hill Contra Costa 37.94542
#           lng        cities       county n_rest
# 181 -122.0537 Pleasant Hill Contra Costa      1
# [1] "consultando 182 de 504"
#     id_rest street_num street_name       city county_name      lat       lng
# 182    3405        239 main st # a pleasanton     Alameda 37.65808 -121.8782
#         cities  county n_rest
# 182 Pleasanton Alameda      1
# [1] "consultando 183 de 504"
#     id_rest street_num             street_name     city  county_name      lat
# 183    3418       2800 hilltop mall rd ste 250 richmond Contra Costa 37.98191
#           lng   cities       county n_rest
# 183 -122.3324 Richmond Contra Costa      1
# [1] "consultando 184 de 504"
#     id_rest street_num street_name                city county_name      lat
# 184    3435        415   grand ave south san francisco   San Mateo 37.65551
#           lng              cities    county n_rest
# 184 -122.4131 South San Francisco San Mateo      1
# [1] "consultando 185 de 504"
#     id_rest street_num      street_name                city county_name
# 185    3436       2284 westborough blvd south san francisco   San Mateo
#          lat       lng              cities    county n_rest
# 185 37.64366 -122.4528 South San Francisco San Mateo      1
# [1] "consultando 186 de 504"
#     id_rest street_num street_name       city county_name      lat       lng
# 186    3446         66     club dr san carlos   San Mateo 37.50322 -122.2851
#         cities    county n_rest
# 186 San Carlos San Mateo      1
# [1] "consultando 187 de 504"
#     id_rest street_num     street_name       city county_name     lat       lng
# 187    3447       1188 san carlos ave. san carlos   San Mateo 37.5068 -122.2613
#         cities    county n_rest
# 187 San Carlos San Mateo      1
# [1] "consultando 188 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 188    3465        675    broadway san francisco San Francisco 37.79749
#           lng        cities        county n_rest
# 188 -122.4081 San Francisco San Francisco      1
# [1] "consultando 189 de 504"
#     id_rest street_num           street_name     city county_name      lat
# 189    3536       1646 saratoga sunnyvale rd san jose Santa Clara 37.29481
#           lng   cities      county n_rest
# 189 -122.0313 San Jose Santa Clara      1
# [1] "consultando 190 de 504"
#     id_rest street_num       street_name     city county_name      lat
# 190    3556       1317 s winchester blvd san jose Santa Clara 37.30075
#           lng   cities      county n_rest
# 190 -121.9511 San Jose Santa Clara      1
# [1] "consultando 191 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 191    3571       3082    story rd san jose Santa Clara 37.35572 -121.8196
#       cities      county n_rest
# 191 San Jose Santa Clara      1
# [1] "consultando 192 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 192    3674        134  robles way vallejo      Solano 38.08464 -122.2101
#      cities county n_rest
# 192 Vallejo Solano      1
# [1] "consultando 193 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 193    3676       2215 sonoma blvd vallejo      Solano 38.10648 -122.2551
#      cities county n_rest
# 193 Vallejo Solano      1
# [1] "consultando 194 de 504"
#     id_rest street_num  street_name        city county_name      lat       lng
# 194    3695       1439 freedom blvd watsonville  Santa Cruz 36.92751 -121.7669
#          cities     county n_rest
# 194 Watsonville Santa Cruz      1
# [1] "consultando 195 de 504"
#     id_rest street_num street_name      city county_name      lat       lng
# 195    3704       1686 s. wolfe rd sunnyvale Santa Clara 37.33848 -122.0139
#        cities      county n_rest
# 195 Sunnyvale Santa Clara      1
# [1] "consultando 196 de 504"
#     id_rest street_num street_name city county_name      lat       lng cities
# 196    3714        829     main st napa        Napa 38.29812 -122.2849   Napa
#     county n_rest
# 196   Napa      1
# [1] "consultando 197 de 504"
#     id_rest street_num     street_name     city county_name      lat       lng
# ...
#     id_rest street_num street_name     city county_name      lat       lng
# 442    8460        890    emory st san jose Santa Clara 37.34062 -121.9175
#       cities      county n_rest
# 442 San Jose Santa Clara      1
# [1] "consultando 443 de 504"
#     id_rest street_num          street_name        city county_name      lat
# 443    8483      15251 hesperian blvd ste 3 san leandro     Alameda 37.69783
#           lng      cities  county n_rest
# 443 -122.1304 San Leandro Alameda      1
# [1] "consultando 444 de 504"
#     id_rest street_num               street_name      city  county_name
# 444    8492       2550 san ramon valley blvd # k san ramon Contra Costa
#          lat       lng    cities       county n_rest
# 444 37.77283 -121.9739 San Ramon Contra Costa      1
# [1] "consultando 445 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 445    8540       1412     polk st san francisco San Francisco 37.78992
#           lng        cities        county n_rest
# 445 -122.4203 San Francisco San Francisco      1
# [1] "consultando 446 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 446    8547       2884  geary blvd san francisco San Francisco 37.78237
#           lng        cities        county n_rest
# 446 -122.4499 San Francisco San Francisco      1
# [1] "consultando 447 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 447    8560        250 napoleon st san francisco San Francisco 37.74676
#           lng        cities        county n_rest
# 447 -122.4009 San Francisco San Francisco      1
# [1] "consultando 448 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 448    8606       1245  jacklin rd milpitas Santa Clara 37.44777 -121.8881
#       cities      county n_rest
# 448 Milpitas Santa Clara      1
# [1] "consultando 449 de 504"
#     id_rest street_num    street_name          city   county_name      lat
# 449    8679        150 pacific avenue san francisco San Francisco 37.79799
#           lng        cities        county n_rest
# 449 -122.3991 San Francisco San Francisco      1
# [1] "consultando 450 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 450    8693          7             san francisco San Francisco 37.77713
#           lng        cities        county n_rest
# 450 -122.4196 San Francisco San Francisco      1
# [1] "consultando 451 de 504"
#     id_rest street_num street_name        city county_name      lat       lng
# 451    8722      13775   e 14th st san leandro     Alameda 37.71491 -122.1428
#          cities  county n_rest
# 451 San Leandro Alameda      1
# [1] "consultando 452 de 504"
#     id_rest street_num      street_name         city county_name      lat
# 452    8767         60 corte madera ave corte madera       Marin 37.92695
#           lng       cities county n_rest
# 452 -122.5309 Corte Madera  Marin      1
# [1] "consultando 453 de 504"
#     id_rest street_num     street_name       city county_name      lat
# 453    8815         49 municipal wharf santa cruz  Santa Cruz 36.95894
#           lng     cities     county n_rest
# 453 -122.0183 Santa Cruz Santa Cruz      1
# [1] "consultando 454 de 504"
#     id_rest street_num            street_name       city county_name      lat
# 454    8816       4210 cabrillo hwy [route 1] el granada   San Mateo 37.50243
#           lng     cities    county n_rest
# 454 -122.4698 El Granada San Mateo      1
# [1] "consultando 455 de 504"
#     id_rest street_num   street_name     city county_name      lat       lng
# 455    8899       3115 telegraph ave berkeley     Alameda 37.85319 -122.2598
#       cities  county n_rest
# 455 Berkeley Alameda      1
# [1] "consultando 456 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 456    8922       3225  walnut ave fremont     Alameda 37.55037 -121.9792
#      cities  county n_rest
# 456 Fremont Alameda      1
# [1] "consultando 457 de 504"
#     id_rest street_num  street_name    city county_name      lat       lng
# 457    8923      37404 fremont blvd fremont     Alameda 37.55807 -122.0059
#      cities  county n_rest
# 457 Fremont Alameda      1
# [1] "consultando 458 de 504"
#     id_rest street_num street_name city county_name      lat       lng cities
# 458    8932       2044  airport rd napa        Napa 38.21709 -122.2729   Napa
#     county n_rest
# 458   Napa      1
# [1] "consultando 459 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 459    8947       6432   e 14th st oakland     Alameda 37.76307 -122.1946
#      cities  county n_rest
# 459 Oakland Alameda      1
# [1] "consultando 460 de 504"
#     id_rest street_num  street_name     city  county_name      lat       lng
# 460    8955       3419 cutting blvd richmond Contra Costa 37.92559 -122.3364
#       cities       county n_rest
# 460 Richmond Contra Costa      1
# [1] "consultando 461 de 504"
#     id_rest street_num            street_name        city county_name      lat
# 461    8964        699 lewelling blvd ste 180 san leandro     Alameda 37.68776
#           lng      cities  county n_rest
# 461 -122.1383 San Leandro Alameda      1
# [1] "consultando 462 de 504"
#     id_rest street_num   street_name      city county_name     lat       lng
# 462    8977       2882 kitty hawk rd livermore     Alameda 37.7001 -121.8167
#        cities  county n_rest
# 462 Livermore Alameda      1
# [1] "consultando 463 de 504"
#     id_rest street_num street_name       city county_name      lat       lng
# 463    8984       2400   midway dr santa rosa      Sonoma 38.44605 -122.6867
#         cities county n_rest
# 463 Santa Rosa Sonoma      1
# [1] "consultando 464 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 464    8988        171 ofarrell st san francisco San Francisco 37.78618
#           lng        cities        county n_rest
# 464 -122.4076 San Francisco San Francisco      1
# [1] "consultando 465 de 504"
#     id_rest street_num street_name                city county_name     lat
# 465    9005        101   brentwood south san francisco   San Mateo 37.6412
#           lng              cities    county n_rest
# 465 -122.4254 South San Francisco San Mateo      1
# [1] "consultando 466 de 504"
#     id_rest street_num    street_name     city county_name     lat       lng
# 466    9014        831 w hamilton ave campbell Santa Clara 37.2948 -121.9638
#       cities      county n_rest
# 466 Campbell Santa Clara      1
# [1] "consultando 467 de 504"
#     id_rest street_num      street_name     city county_name      lat       lng
# 467    9041       5363 camden ave # 102 san jose Santa Clara 37.24106 -121.9055
#       cities      county n_rest
# 467 San Jose Santa Clara      1
# [1] "consultando 468 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 468    9061       2204        22nd oakland     Alameda 37.79056 -122.2321
#      cities  county n_rest
# 468 Oakland Alameda      1
# [1] "consultando 469 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 469    9095       1619  webster st alameda     Alameda 37.77586 -122.2768
#      cities  county n_rest
# 469 Alameda Alameda      1
# [1] "consultando 470 de 504"
#     id_rest street_num    street_name   city  county_name      lat       lng
# 470    9165         23 orinda way # h orinda Contra Costa 37.88173 -122.1881
#     cities       county n_rest
# 470 Orinda Contra Costa      1
# [1] "consultando 471 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 471    9195       1331        polk san francisco San Francisco 37.78924
#           lng        cities        county n_rest
# 471 -122.4206 San Francisco San Francisco      1
# [1] "consultando 472 de 504"
#     id_rest street_num street_name          city   county_name     lat
# 472    9215        500      haight san francisco San Francisco 37.7722
#           lng        cities        county n_rest
# 472 -122.4306 San Francisco San Francisco      1
# [1] "consultando 473 de 504"
#     id_rest street_num         street_name      city county_name      lat
# 473    9236        500 n lawrence expy # b sunnyvale Santa Clara 37.38176
#           lng    cities      county n_rest
# 473 -121.9953 Sunnyvale Santa Clara      1
# [1] "consultando 474 de 504"
#     id_rest street_num street_name          city   county_name    lat       lng
# 474    9241       2121 clement st. san francisco San Francisco 37.782 -122.4821
#            cities        county n_rest
# 474 San Francisco San Francisco      1
# [1] "consultando 475 de 504"
#     id_rest street_num  street_name    city county_name      lat       lng
# 475    9306      43691 mission blvd fremont     Alameda 37.52637 -121.9185
#      cities  county n_rest
# 475 Fremont Alameda      1
# [1] "consultando 476 de 504"
#     id_rest street_num street_name          city   county_name      lat
# 476    9317       2301     clement san francisco San Francisco 37.78181
#          lng        cities        county n_rest
# 476 -122.484 San Francisco San Francisco      1
# [1] "consultando 477 de 504"
#     id_rest street_num street_name   city county_name      lat       lng cities
# 477    9349       5729  jarvis ave newark     Alameda 37.55335 -122.0484 Newark
#      county n_rest
# 477 Alameda      1
# [1] "consultando 478 de 504"
#     id_rest street_num          street_name      city county_name      lat
# 478    9393        590 old san francisco rd sunnyvale Santa Clara 37.36705
#           lng    cities      county n_rest
# 478 -122.0236 Sunnyvale Santa Clara      1
# [1] "consultando 479 de 504"
#     id_rest street_num  street_name     city county_name      lat       lng
# 479    9394         80 n. market st san jose Santa Clara 37.33673 -121.8926
#       cities      county n_rest
# 479 San Jose Santa Clara      1
# [1] "consultando 480 de 504"
#     id_rest street_num       street_name     city county_name      lat
# 480    9433        824 university avenue berkeley     Alameda 37.86768
#           lng   cities  county n_rest
# 480 -122.2978 Berkeley Alameda      1
# [1] "consultando 481 de 504"
#     id_rest street_num street_name city county_name      lat       lng cities
# 481    9462       1155   lokoya rd napa        Napa 38.36518 -122.4233   Napa
#     county n_rest
# 481   Napa      1
# [1] "consultando 482 de 504"
#     id_rest street_num             street_name      city county_name      lat
# 482    9514      15466 los gatos blvd ste 106a los gatos Santa Clara 37.24443
#           lng    cities      county n_rest
# 482 -121.9581 Los Gatos Santa Clara      1
# [1] "consultando 483 de 504"
#     id_rest street_num     street_name     city county_name      lat       lng
# 483    9519        113 n milpitas blvd milpitas Santa Clara 37.43507 -121.9011
#       cities      county n_rest
# 483 Milpitas Santa Clara      1
# [1] "consultando 484 de 504"
#     id_rest street_num street_name    city county_name      lat       lng
# 484    9532       5916 college ave oakland     Alameda 37.84762 -122.2519
#      cities  county n_rest
# 484 Oakland Alameda      1
# [1] "consultando 485 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 485    9549        840   willow st san jose Santa Clara 37.31027 -121.8958
#       cities      county n_rest
# 485 San Jose Santa Clara      1
# [1] "consultando 486 de 504"
#     id_rest street_num  street_name     city county_name      lat      lng
# 486    9552       1794 jonathan ave san jose Santa Clara 37.29919 -121.887
#       cities      county n_rest
# 486 San Jose Santa Clara      1
# [1] "consultando 487 de 504"
#     id_rest street_num           street_name       city  county_name      lat
# 487    1150      11090 san pablo ave ste 200 el cerrito Contra Costa 37.91837
#           lng     cities       county n_rest
# 487 -122.3126 El Cerrito Contra Costa      1
# [1] "consultando 488 de 504"
#     id_rest street_num street_name          city county_name      lat       lng
# 488    1828       1351 ormonde way mountain view Santa Clara 37.40407 -122.0817
#            cities      county n_rest
# 488 Mountain View Santa Clara      1
# [1] "consultando 489 de 504"
#     id_rest street_num         street_name       city  county_name      lat
# 489    3078      11760 san pablo ave ste c el cerrito Contra Costa 37.92751
#           lng     cities       county n_rest
# 489 -122.3197 El Cerrito Contra Costa      1
# [1] "consultando 490 de 504"
#     id_rest street_num street_name          city county_name      lat       lng
# 490    3230        304   castro st mountain view Santa Clara 37.39255 -122.0802
#            cities      county n_rest
# 490 Mountain View Santa Clara      1
# [1] "consultando 491 de 504"
#     id_rest street_num street_name          city county_name      lat       lng
# 491    3232        134   castro st mountain view Santa Clara 37.39471 -122.0788
#            cities      county n_rest
# 491 Mountain View Santa Clara      1
# [1] "consultando 492 de 504"
#     id_rest street_num      street_name          city county_name      lat
# 492    4625        856 w el camino real mountain view Santa Clara 37.38669
#           lng        cities      county n_rest
# 492 -122.0849 Mountain View Santa Clara      1
# [1] "consultando 493 de 504"
#     id_rest street_num        street_name       city  county_name      lat
# 493    6144      10887 san pablo ave # 89 el cerrito Contra Costa 37.91522
#           lng     cities       county n_rest
# 493 -122.3117 El Cerrito Contra Costa      1
# [1] "consultando 494 de 504"
#     id_rest street_num      street_name          city county_name      lat
# 494    6171        286 w el camino real mountain view Santa Clara 37.38331
#           lng        cities      county n_rest
# 494 -122.0783 Mountain View Santa Clara      1
# [1] "consultando 495 de 504"
#     id_rest street_num street_name          city county_name      lat       lng
# 495    6175        975   w dana st mountain view Santa Clara 37.39305 -122.0816
#            cities      county n_rest
# 495 Mountain View Santa Clara      1
# [1] "consultando 496 de 504"
#     id_rest street_num street_name          city county_name      lat       lng
# 496    6755       1929   latham st mountain view Santa Clara 37.39432 -122.0963
#            cities      county n_rest
# 496 Mountain View Santa Clara      1
# [1] "consultando 497 de 504"
#     id_rest street_num  street_name          city county_name      lat
# 497    7708        867 w evelyn ave mountain view Santa Clara 37.39515
#           lng        cities      county n_rest
# 497 -122.0787 Mountain View Santa Clara      1
# [1] "consultando 498 de 504"
#     id_rest street_num      street_name          city county_name      lat
# 498    7717       1955 w el camino real mountain view Santa Clara 37.39399
#           lng        cities      county n_rest
# 498 -122.0985 Mountain View Santa Clara      1
# [1] "consultando 499 de 504"
#     id_rest street_num street_name       city  county_name      lat       lng
# 499    9135       1811      elm st el cerrito Contra Costa 37.92595 -122.3141
#         cities       county n_rest
# 499 El Cerrito Contra Costa      1
# [1] "consultando 500 de 504"
#     id_rest street_num street_name   city county_name      lat       lng
# 500     357      26270     dolores carmel    Monterey 36.54187 -121.9226
#                cities   county n_rest
# 500 Carmel-by-the-Sea Monterey      1
# [1] "consultando 501 de 504"
#     id_rest street_num                     street_name    city county_name lat
# 501    2645          1 (2 miles south of big surneine) big sur              NA
#     lng cities county n_rest
# 501  NA   <NA>   <NA>      0
# [1] "consultando 502 de 504"
#     id_rest street_num street_name     city county_name      lat       lng
# 502    5895        994  roswell st marietta        Cobb 33.95066 -84.52321
#       cities county n_rest
# 502 Marietta   Cobb      1
# [1] "consultando 503 de 504"
#     id_rest street_num                        street_name       city
# 503    5991          2 mi. n.e. taloe city in lake forest tahoe city
#     county_name lat lng cities county n_rest
# 503              NA  NA   <NA>   <NA>      0
# [1] "consultando 504 de 504"
#     id_rest street_num street_name      city county_name lat lng cities county
# 504    6076       1154  robson st. vancouver              NA  NA   <NA>   <NA>
#     n_rest
# 504      0

# %% [markdown]
# Chequeamos que los resgistros sin info sean solo 4

# %%
# b)

location_no_na <- location %>% 
 filter(!(is.na(lat) | is.na(lng) & !(id_rest %in% c(6527,2645,5991,6076)) ))

location <- bind_rows(location_no_na,location_busqueda) #Recordar para unir dataframes

filter(location,is.na(lat) | is.na(lng) ) # 4 registros con lat o lng con valor NA
# Out:
#   id_rest street_num street_name                        city       county_name
# 1 6527     270       carneros ave                       aromas     San Benito
# 2 2645       1       (2 miles south of big surneine)    big sur
# 3 5991       2       mi. n.e. taloe city in lake forest tahoe city
# 4 6076    1154       robson st.                         vancouver
#   lat lng cities county n_rest
# 1 NA  NA  NA     NA     0
# 2 NA  NA  NA     NA     0
# 3 NA  NA  NA     NA     0
# 4 NA  NA  NA     NA     0

# %% [markdown]
# **P4) (3pts)** Utilizando ggplot, genere un gráfico que muestre mendiante puntos,  a cada restaurant, donde el eje _x_ contiene la longitud y el eje _y_ la latitud. Considere añadir la capa `borders()`con parámetros `database = "county",regions ="CA"`.
#
# **NOTA:** Para una mejor visualización, considere filtrar la tabla location a aquellos casos  que cumplan con `lat <= 39 & lat >= 36 & lng <=-121 & lng >=-123` e incuya los parámetros `xlim` y `ylim` dentro de la función borders para acotar la visualización.
#
#
# **NOTA2:** Es probable que requiera la instalación del package `maps`

# %%
install.packages("maps")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
location %>% 
  filter(lat <= 39 & lat >= 36 & lng <=-121 & lng >=-123) %>%
  ggplot() +
  aes(x = lng, y = lat) +
  geom_point(alpha = 0.5) +
  borders(database = "county",regions ="CA", xlim = c(-123,-121.), ylim = c(36,38.75))
# Out:
# plot without title

# %% [markdown]
# **P5) (4pts)** Replique el gráfico anterior, pero coloree cada punto según la variable `type_review` creada en la pregunta P5a.

# %%
location %>% 
  filter(lat <= 39 & lat >= 36 & lng <=-121 & lng >=-123) %>%
  left_join(general, by = c("id_rest" = "id_restaurant")) %>% 
  left_join(resumen, by =c("city", "food_type")) %>%
  ggplot() +
  aes(x = lng, y = lat, color = type_review) +
  geom_point(alpha = 0.5) +
  borders(database = "county",regions ="CA", xlim = c(-123,-121.), ylim = c(36,38.75))
# Out:
# plot without title

# %% [markdown]
# **P6) (2pt)** Comente el gráfico anterior. Para ello considere las siguientes preguntas como "guía";
#   * ¿Hay condados con mayor "densidad" de restaurants?
#   * ¿Existirá alguna posible relación entre la ubicación del restaurant  y su `type_review`?
#   * ¿Qué type_review es el más predominante en el mapa?

# %%
# Según el gráfico al para las latitudes entre 37 y 38 hay mayor densidad de restaurantes que en otros condados
# Según el gráfico no se observa una aparente relación entre la ubicación y type review (no hay separación clara entre lo rojo y lo verde)
# Verde
